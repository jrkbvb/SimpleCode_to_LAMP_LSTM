# %% [markdown]
# ### Imports

# %%
from data_functions import *
import copy
import os
import logging
import traceback

# sys.path.insert(1, "H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM")

import torch
import numpy as np
import matplotlib.pyplot as plt
import random
import time
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from plot_lstm_results import plot_lstm_results
from network_models import LSTM
from train_test import train, test
from S2LDataset import S2LDataset
from print_error_report import print_error_report
from objective_functions import objective_function

# On the line below, specifiy after "from" which file the user inputs are coming from.
from input_template import (
    UserInputArgs,
    PlottingArgs,
    DataInfoArgs,
    SaveDataArgs,
    DerivedArgs,
)
from load_and_standardize import load_and_standardize
from reshape_for_time_resolution import reshape_for_time_resolution, reshape_full_series
from save_lstm import save_lstm_info, load_lstm_info
from save_lstm_results import save_lstm_results, save_lstm_test_results
from unstandardize_all_data import unstandardize_all_data

import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import matplotlib.pyplot as plt

# %% [markdown]
# ### Description
# Create and train Bimodal LSTMS 5 samples from their bucket.  Compare to the TL MED LSTMS where each MED LSTM was fed 5 records, randomly selected.

# %% [markdown]
# ### Functions

# %%
print("Cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    torch.cuda.empty_cache()  # to avoid some rare errors.

# Check if using CPU or GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set parameters
args = UserInputArgs()
plot_args = PlottingArgs()
data_info_args = DataInfoArgs()
save_data_args = SaveDataArgs()

# args.training_mode = False

# Load original LSTM
# args.model_load_filename = 'MED2_30'
# network, std_factors = load_lstm_info(args)
# network.to(device)
# Out:
# Cuda available: True

# %% [markdown]
# ### Bimodal Network

# %% [markdown]
# Create and test bimodal network on N randomly selected realiztions.  Return training files for future use with TL network

# %%
def create_and_train_LSTM(experiment='', N=5):
    '''Create, train, and save a new LSTM on bimodal test sets.  Train on N randomly selected records for each bucket.'''

    # ID Experiment for tracking
    print("EXPERIMENT: ", experiment)

    # Setup GPU Support
    print("Cuda available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        torch.cuda.empty_cache()  # to avoid some rare errors.

    # Check if using CPU or GPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Set parameters
    args = UserInputArgs()
    plot_args = PlottingArgs()
    data_info_args = DataInfoArgs()
    save_data_args = SaveDataArgs()

    # Create list of eligible files to train on
    # exp_PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\{experiment}'
    exp_PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\{experiment}'
    files = [f for f in os.listdir(exp_PATH + '\\LAMP_files') if f.endswith('1.mot')]

    # randomly select N num_files to train on
    train_files = np.random.choice(files, size=N, replace = False)
    val_files = [f.replace('1.mot','2.mot') for f in train_files]

    # Shorten val_files to 20% of train_files, randomly selected
    val_files = np.random.choice(val_files, size=int(.2*len(val_files)), replace = False)

    # establish the lamp and sc training file paths
    data_info_args.train_lamp = [exp_PATH + '\\LAMP_files\\' + f.removesuffix('.mot') for f in train_files]
    data_info_args.train_sc = [exp_PATH + '\\SimpleCode_files\\' + f.replace('LAMP','SC').removesuffix('.mot') for f in train_files]

    # establish the lamp and sc validation file paths
    data_info_args.val_lamp= [exp_PATH + '\\LAMP_files\\' + f.removesuffix('.mot') for f in val_files]
    data_info_args.val_sc = [exp_PATH + '\\SimpleCode_files\\' + f.replace('LAMP','SC').removesuffix('.mot') for f in val_files]

    # Setup Derived Args
    derived_args = DerivedArgs(args, data_info_args)

    # Read in and standardize the training and validation data
    train_input, train_target, std_factors, train_sc = load_and_standardize(data_info_args.train_sc, data_info_args.train_lamp, args, std_factors=[])
    val_input, val_target, val_sc = load_and_standardize(data_info_args.val_sc, data_info_args.val_lamp, args, std_factors)

    print('Std_factors: ', std_factors)

    # Create the LSTM
    network = LSTM(args.input_size,args.hidden_size,args.num_layers,args.output_size,args.bi_directional,args.dropout,).to(device)

    # Update the save path
    args.model_save_filename = exp_PATH + f'\\{experiment}_BiMod_{N}_LSTM_v1'

    # Reshape the data to take into account the time resolution
    train_input, train_target = reshape_for_time_resolution(train_input, train_target, args)
    val_input, val_target = reshape_for_time_resolution(val_input, val_target, args)

    # Create Dataset objects for each of our train/val/test sets
    train_dataset = S2LDataset(train_input, train_target)
    val_dataset = S2LDataset(val_input, val_target)

    # Create a PyTorch dataloader for each train/val set. Test set isn't needed until later
    train_loader = DataLoader(train_dataset, batch_size=derived_args.train_batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=derived_args.val_batch_size)

    # Display realization and batch numbers
    print("No of train realizations: ", derived_args.num_train_realizations)
    print("No of val realizations: ", derived_args.num_val_realizations)
    print("No of test realizations: ", derived_args.num_test_realizations)
    print("No of realizations: ", derived_args.num_realizations)
    print("Train batch size: ", derived_args.train_batch_size)
    realization_length = train_input.shape[1] * args.time_res

    # initialize our optimizer. We'll use Adam
    optimizer = torch.optim.Adam(network.parameters(), lr=args.lr)

    # Begin Training
    best_val_loss = float("inf")
    best_loss_counter = 0
    print("\n Beginning Training")
    start_time = time.time()
    for epoch in range(1, args.epochs + 1):
        train_loss = train(network, device, train_loader, optimizer, args.train_fun_hyp)
        val_loss = test(network, device, val_loader, args.val_fun_hyp)
        if val_loss < 0.95 * best_val_loss:
            best_val_loss = val_loss
            best_loss_counter = 0
            torch.save(network.state_dict(), "recently_trained_model.pt")
        else:
            best_loss_counter += 1
        if best_loss_counter > 30:
            break
        print("Train Epoch: {:02d} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tCounter: {:02d}".format(epoch, train_loss, val_loss, best_loss_counter))
    print("Training Done\n")
    end_time = time.time()
    trainTime = end_time - start_time
    print("Training Time: ", trainTime)

    # restoring the best found network based on validation data
    network.load_state_dict(torch.load("recently_trained_model.pt"))

    # Save the LSTM
    save_lstm_info(network.state_dict(), args, data_info_args, std_factors)

    # Return the Training time
    return trainTime, train_files
    print('\n\n')

# %%
PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\'
ignore = ['Cases_files', '.ipynb_checkpoints','SecAngleOnly_test','__pycache__']
t = []
training_files = {}
exp_list = []
for exp in os.listdir(PATH):
    if os.path.isdir(PATH + exp) and exp not in ignore:
        try:
            train_time, training_files[exp] = create_and_train_LSTM(exp,N=5)
            t.append(train_time)
            exp_list.append(exp)
        except Exception as e:
            logging.error(traceback.format_exc())
            print('ERROR in ', exp)
            print('\n\n\n\n')
            continue
for key, value in training_files.items():
    print(key +': ', value)
# Out:
# EXPERIMENT:  aavs
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.0719600439492565, 1.751505750798621, 0.2135408032988994, 5.378883964342058, -0.04676330350934308, 1.5127634393040224, -0.003049737432539187, 2.018710700262407, 1.9089328558622456, 1.7316879280965585, -0.09767330089508665, 8.103249195285157, 0.05784179532746302, 2.0538861934804564]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.525320 	Validation Loss: 0.178483 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.168714 	Validation Loss: 0.081989 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.119755 	Validation Loss: 0.070800 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.097621 	Validation Loss: 0.056626 	Counter: 00
# Train Epoch: 05 	Training Loss: 0.081941 	Validation Loss: 0.049034 	Counter: 00
# Train Epoch: 06 	Training Loss: 0.071945 	Validation Loss: 0.046961 	Counter: 01
# Train Epoch: 07 	Training Loss: 0.069253 	Validation Loss: 0.037164 	Counter: 00
# Train Epoch: 08 	Training Loss: 0.062177 	Validation Loss: 0.039647 	Counter: 01
# Train Epoch: 09 	Training Loss: 0.055481 	Validation Loss: 0.031629 	Counter: 00
# Train Epoch: 10 	Training Loss: 0.050777 	Validation Loss: 0.028789 	Counter: 00
# Train Epoch: 11 	Training Loss: 0.041244 	Validation Loss: 0.024311 	Counter: 00
# Train Epoch: 12 	Training Loss: 0.039562 	Validation Loss: 0.031237 	Counter: 01
# Train Epoch: 13 	Training Loss: 0.036731 	Validation Loss: 0.026740 	Counter: 02
# Train Epoch: 14 	Training Loss: 0.040559 	Validation Loss: 0.023486 	Counter: 03
# Train Epoch: 15 	Training Loss: 0.052756 	Validation Loss: 0.033312 	Counter: 04
# Train Epoch: 16 	Training Loss: 0.040133 	Validation Loss: 0.023720 	Counter: 05
# Train Epoch: 17 	Training Loss: 0.029917 	Validation Loss: 0.024331 	Counter: 06
# Train Epoch: 18 	Training Loss: 0.028911 	Validation Loss: 0.022336 	Counter: 00
# Train Epoch: 19 	Training Loss: 0.034986 	Validation Loss: 0.021181 	Counter: 00
# Train Epoch: 20 	Training Loss: 0.031196 	Validation Loss: 0.019830 	Counter: 00
# Train Epoch: 21 	Training Loss: 0.026236 	Validation Loss: 0.020429 	Counter: 01
# Train Epoch: 22 	Training Loss: 0.024024 	Validation Loss: 0.017734 	Counter: 00
# Train Epoch: 23 	Training Loss: 0.022922 	Validation Loss: 0.018001 	Counter: 01
# Train Epoch: 24 	Training Loss: 0.022224 	Validation Loss: 0.019127 	Counter: 02
# Train Epoch: 25 	Training Loss: 0.023063 	Validation Loss: 0.016796 	Counter: 00
# Train Epoch: 26 	Training Loss: 0.023158 	Validation Loss: 0.038423 	Counter: 01
# Train Epoch: 27 	Training Loss: 0.037384 	Validation Loss: 0.026091 	Counter: 02
# Train Epoch: 28 	Training Loss: 0.022665 	Validation Loss: 0.018516 	Counter: 03
# Train Epoch: 29 	Training Loss: 0.022900 	Validation Loss: 0.019018 	Counter: 04
# Train Epoch: 30 	Training Loss: 0.019272 	Validation Loss: 0.016433 	Counter: 05
# Train Epoch: 31 	Training Loss: 0.017842 	Validation Loss: 0.016753 	Counter: 06
# Train Epoch: 32 	Training Loss: 0.023803 	Validation Loss: 0.018224 	Counter: 07
# Train Epoch: 33 	Training Loss: 0.018407 	Validation Loss: 0.016753 	Counter: 08
# Train Epoch: 34 	Training Loss: 0.016640 	Validation Loss: 0.017418 	Counter: 09
# Train Epoch: 35 	Training Loss: 0.019585 	Validation Loss: 0.017172 	Counter: 10
# Train Epoch: 36 	Training Loss: 0.022200 	Validation Loss: 0.016619 	Counter: 11
# Train Epoch: 37 	Training Loss: 0.015776 	Validation Loss: 0.015168 	Counter: 00
# Train Epoch: 38 	Training Loss: 0.015975 	Validation Loss: 0.019262 	Counter: 01
# Train Epoch: 39 	Training Loss: 0.027679 	Validation Loss: 0.025210 	Counter: 02
# Train Epoch: 40 	Training Loss: 0.023303 	Validation Loss: 0.017353 	Counter: 03
# Train Epoch: 41 	Training Loss: 0.015678 	Validation Loss: 0.015163 	Counter: 04
# Train Epoch: 42 	Training Loss: 0.014845 	Validation Loss: 0.015371 	Counter: 05
# Train Epoch: 43 	Training Loss: 0.014238 	Validation Loss: 0.014732 	Counter: 06
# Train Epoch: 44 	Training Loss: 0.014468 	Validation Loss: 0.015477 	Counter: 07
# Train Epoch: 45 	Training Loss: 0.014192 	Validation Loss: 0.014848 	Counter: 08
# Train Epoch: 46 	Training Loss: 0.012561 	Validation Loss: 0.014332 	Counter: 00
# Train Epoch: 47 	Training Loss: 0.012790 	Validation Loss: 0.014233 	Counter: 01
# Train Epoch: 48 	Training Loss: 0.014895 	Validation Loss: 0.026588 	Counter: 02
# Train Epoch: 49 	Training Loss: 0.015438 	Validation Loss: 0.014778 	Counter: 03
# Train Epoch: 50 	Training Loss: 0.011791 	Validation Loss: 0.014496 	Counter: 04
# Train Epoch: 51 	Training Loss: 0.011476 	Validation Loss: 0.014266 	Counter: 05
# Train Epoch: 52 	Training Loss: 0.012577 	Validation Loss: 0.014196 	Counter: 06
# Train Epoch: 53 	Training Loss: 0.011337 	Validation Loss: 0.016132 	Counter: 07
# Train Epoch: 54 	Training Loss: 0.011879 	Validation Loss: 0.017522 	Counter: 08
# Train Epoch: 55 	Training Loss: 0.012971 	Validation Loss: 0.015241 	Counter: 09
# Train Epoch: 56 	Training Loss: 0.017442 	Validation Loss: 0.016204 	Counter: 10
# Train Epoch: 57 	Training Loss: 0.011443 	Validation Loss: 0.014016 	Counter: 11
# Train Epoch: 58 	Training Loss: 0.011946 	Validation Loss: 0.014807 	Counter: 12
# Train Epoch: 59 	Training Loss: 0.021565 	Validation Loss: 0.016618 	Counter: 13
# Train Epoch: 60 	Training Loss: 0.014832 	Validation Loss: 0.015196 	Counter: 14
# Train Epoch: 61 	Training Loss: 0.011890 	Validation Loss: 0.014369 	Counter: 15
# Train Epoch: 62 	Training Loss: 0.011384 	Validation Loss: 0.014396 	Counter: 16
# Train Epoch: 63 	Training Loss: 0.009840 	Validation Loss: 0.015857 	Counter: 17
# Train Epoch: 64 	Training Loss: 0.010273 	Validation Loss: 0.017401 	Counter: 18
# Train Epoch: 65 	Training Loss: 0.010697 	Validation Loss: 0.013517 	Counter: 00
# Train Epoch: 66 	Training Loss: 0.010141 	Validation Loss: 0.013946 	Counter: 01
# Train Epoch: 67 	Training Loss: 0.011173 	Validation Loss: 0.014454 	Counter: 02
# Train Epoch: 68 	Training Loss: 0.010483 	Validation Loss: 0.013972 	Counter: 03
# Train Epoch: 69 	Training Loss: 0.016634 	Validation Loss: 0.015634 	Counter: 04
# Train Epoch: 70 	Training Loss: 0.009752 	Validation Loss: 0.013913 	Counter: 05
# Train Epoch: 71 	Training Loss: 0.009241 	Validation Loss: 0.017065 	Counter: 06
# Train Epoch: 72 	Training Loss: 0.014034 	Validation Loss: 0.018148 	Counter: 07
# Train Epoch: 73 	Training Loss: 0.014081 	Validation Loss: 0.016878 	Counter: 08
# Train Epoch: 74 	Training Loss: 0.009400 	Validation Loss: 0.014098 	Counter: 09
# Train Epoch: 75 	Training Loss: 0.009827 	Validation Loss: 0.016683 	Counter: 10
# Train Epoch: 76 	Training Loss: 0.012783 	Validation Loss: 0.014439 	Counter: 11
# Train Epoch: 77 	Training Loss: 0.008480 	Validation Loss: 0.013203 	Counter: 12
# Train Epoch: 78 	Training Loss: 0.007987 	Validation Loss: 0.013371 	Counter: 13
# Train Epoch: 79 	Training Loss: 0.008257 	Validation Loss: 0.013343 	Counter: 14
# Train Epoch: 80 	Training Loss: 0.007696 	Validation Loss: 0.013455 	Counter: 15
# Train Epoch: 81 	Training Loss: 0.008322 	Validation Loss: 0.013860 	Counter: 16
# Train Epoch: 82 	Training Loss: 0.007432 	Validation Loss: 0.013779 	Counter: 17
# Train Epoch: 83 	Training Loss: 0.012269 	Validation Loss: 0.020977 	Counter: 18
# Train Epoch: 84 	Training Loss: 0.013354 	Validation Loss: 0.018625 	Counter: 19
# Train Epoch: 85 	Training Loss: 0.010997 	Validation Loss: 0.015061 	Counter: 20
# Train Epoch: 86 	Training Loss: 0.008296 	Validation Loss: 0.013014 	Counter: 21
# Train Epoch: 87 	Training Loss: 0.007005 	Validation Loss: 0.013470 	Counter: 22
# Train Epoch: 88 	Training Loss: 0.006834 	Validation Loss: 0.013086 	Counter: 23
# Train Epoch: 89 	Training Loss: 0.007863 	Validation Loss: 0.013790 	Counter: 24
# Train Epoch: 90 	Training Loss: 0.008294 	Validation Loss: 0.013379 	Counter: 25
# Train Epoch: 91 	Training Loss: 0.006212 	Validation Loss: 0.013347 	Counter: 26
# Train Epoch: 92 	Training Loss: 0.007585 	Validation Loss: 0.013732 	Counter: 27
# Train Epoch: 93 	Training Loss: 0.006681 	Validation Loss: 0.012994 	Counter: 28
# Train Epoch: 94 	Training Loss: 0.007524 	Validation Loss: 0.013796 	Counter: 29
# Train Epoch: 95 	Training Loss: 0.010389 	Validation Loss: 0.014973 	Counter: 30
# Training Done
#
# Training Time:  119.6588454246521
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\aavs\aavs_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  avaa
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.07397373352049, 1.8133175607089391, -0.17810989855207007, 7.433454306995165, 0.09630064898689271, 1.4749419622756292, -0.003334651232237133, 2.031135208995688, 1.8758276541931496, 1.8942853056005173, -0.3188768508865387, 8.814287536307267, 0.0721484714493908, 1.4811136947580592]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.701258 	Validation Loss: 0.335471 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.389729 	Validation Loss: 0.169660 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.245694 	Validation Loss: 0.141357 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.176894 	Validation Loss: 0.121357 	Counter: 00
# Train Epoch: 05 	Training Loss: 0.146215 	Validation Loss: 0.125222 	Counter: 01
# Train Epoch: 06 	Training Loss: 0.127105 	Validation Loss: 0.099643 	Counter: 00
# Train Epoch: 07 	Training Loss: 0.113880 	Validation Loss: 0.108073 	Counter: 01
# Train Epoch: 08 	Training Loss: 0.095720 	Validation Loss: 0.080539 	Counter: 00
# Train Epoch: 09 	Training Loss: 0.104873 	Validation Loss: 0.086912 	Counter: 01
# Train Epoch: 10 	Training Loss: 0.096455 	Validation Loss: 0.090587 	Counter: 02
# Train Epoch: 11 	Training Loss: 0.111395 	Validation Loss: 0.083642 	Counter: 03
# Train Epoch: 12 	Training Loss: 0.082457 	Validation Loss: 0.074851 	Counter: 00
# Train Epoch: 13 	Training Loss: 0.079320 	Validation Loss: 0.093693 	Counter: 01
# Train Epoch: 14 	Training Loss: 0.089876 	Validation Loss: 0.081062 	Counter: 02
# Train Epoch: 15 	Training Loss: 0.075930 	Validation Loss: 0.069145 	Counter: 00
# Train Epoch: 16 	Training Loss: 0.069366 	Validation Loss: 0.068297 	Counter: 01
# Train Epoch: 17 	Training Loss: 0.067816 	Validation Loss: 0.072044 	Counter: 02
# Train Epoch: 18 	Training Loss: 0.063940 	Validation Loss: 0.068966 	Counter: 03
# Train Epoch: 19 	Training Loss: 0.076769 	Validation Loss: 0.077627 	Counter: 04
# Train Epoch: 20 	Training Loss: 0.068188 	Validation Loss: 0.068036 	Counter: 05
# Train Epoch: 21 	Training Loss: 0.058518 	Validation Loss: 0.067157 	Counter: 06
# Train Epoch: 22 	Training Loss: 0.065450 	Validation Loss: 0.066870 	Counter: 07
# Train Epoch: 23 	Training Loss: 0.068222 	Validation Loss: 0.067457 	Counter: 08
# Train Epoch: 24 	Training Loss: 0.056394 	Validation Loss: 0.064472 	Counter: 00
# Train Epoch: 25 	Training Loss: 0.058067 	Validation Loss: 0.063706 	Counter: 01
# Train Epoch: 26 	Training Loss: 0.059705 	Validation Loss: 0.066528 	Counter: 02
# Train Epoch: 27 	Training Loss: 0.071535 	Validation Loss: 0.074408 	Counter: 03
# Train Epoch: 28 	Training Loss: 0.081127 	Validation Loss: 0.078349 	Counter: 04
# Train Epoch: 29 	Training Loss: 0.052794 	Validation Loss: 0.061094 	Counter: 00
# Train Epoch: 30 	Training Loss: 0.043186 	Validation Loss: 0.058799 	Counter: 01
# Train Epoch: 31 	Training Loss: 0.046533 	Validation Loss: 0.065658 	Counter: 02
# Train Epoch: 32 	Training Loss: 0.050022 	Validation Loss: 0.058733 	Counter: 03
# Train Epoch: 33 	Training Loss: 0.046644 	Validation Loss: 0.062831 	Counter: 04
# Train Epoch: 34 	Training Loss: 0.054217 	Validation Loss: 0.057764 	Counter: 00
# Train Epoch: 35 	Training Loss: 0.042379 	Validation Loss: 0.056404 	Counter: 01
# Train Epoch: 36 	Training Loss: 0.042437 	Validation Loss: 0.054952 	Counter: 02
# Train Epoch: 37 	Training Loss: 0.042989 	Validation Loss: 0.059399 	Counter: 03
# Train Epoch: 38 	Training Loss: 0.036802 	Validation Loss: 0.058863 	Counter: 04
# Train Epoch: 39 	Training Loss: 0.033633 	Validation Loss: 0.054183 	Counter: 00
# Train Epoch: 40 	Training Loss: 0.041428 	Validation Loss: 0.058686 	Counter: 01
# Train Epoch: 41 	Training Loss: 0.037335 	Validation Loss: 0.059099 	Counter: 02
# Train Epoch: 42 	Training Loss: 0.042043 	Validation Loss: 0.059090 	Counter: 03
# Train Epoch: 43 	Training Loss: 0.041214 	Validation Loss: 0.062331 	Counter: 04
# Train Epoch: 44 	Training Loss: 0.039608 	Validation Loss: 0.054749 	Counter: 05
# Train Epoch: 45 	Training Loss: 0.032234 	Validation Loss: 0.055143 	Counter: 06
# Train Epoch: 46 	Training Loss: 0.029391 	Validation Loss: 0.053753 	Counter: 07
# Train Epoch: 47 	Training Loss: 0.037889 	Validation Loss: 0.065451 	Counter: 08
# Train Epoch: 48 	Training Loss: 0.037400 	Validation Loss: 0.060242 	Counter: 09
# Train Epoch: 49 	Training Loss: 0.031765 	Validation Loss: 0.054448 	Counter: 10
# Train Epoch: 50 	Training Loss: 0.026103 	Validation Loss: 0.052336 	Counter: 11
# Train Epoch: 51 	Training Loss: 0.027758 	Validation Loss: 0.055898 	Counter: 12
# Train Epoch: 52 	Training Loss: 0.026600 	Validation Loss: 0.053020 	Counter: 13
# Train Epoch: 53 	Training Loss: 0.027323 	Validation Loss: 0.054670 	Counter: 14
# Train Epoch: 54 	Training Loss: 0.033662 	Validation Loss: 0.061843 	Counter: 15
# Train Epoch: 55 	Training Loss: 0.029870 	Validation Loss: 0.053207 	Counter: 16
# Train Epoch: 56 	Training Loss: 0.035470 	Validation Loss: 0.058672 	Counter: 17
# Train Epoch: 57 	Training Loss: 0.030531 	Validation Loss: 0.053769 	Counter: 18
# Train Epoch: 58 	Training Loss: 0.025068 	Validation Loss: 0.052085 	Counter: 19
# Train Epoch: 59 	Training Loss: 0.024605 	Validation Loss: 0.054077 	Counter: 20
# Train Epoch: 60 	Training Loss: 0.028418 	Validation Loss: 0.062677 	Counter: 21
# Train Epoch: 61 	Training Loss: 0.036429 	Validation Loss: 0.053016 	Counter: 22
# Train Epoch: 62 	Training Loss: 0.024627 	Validation Loss: 0.060227 	Counter: 23
# Train Epoch: 63 	Training Loss: 0.025781 	Validation Loss: 0.051121 	Counter: 00
# Train Epoch: 64 	Training Loss: 0.022827 	Validation Loss: 0.056147 	Counter: 01
# Train Epoch: 65 	Training Loss: 0.023412 	Validation Loss: 0.057903 	Counter: 02
# Train Epoch: 66 	Training Loss: 0.026409 	Validation Loss: 0.050787 	Counter: 03
# Train Epoch: 67 	Training Loss: 0.028314 	Validation Loss: 0.060275 	Counter: 04
# Train Epoch: 68 	Training Loss: 0.034165 	Validation Loss: 0.065882 	Counter: 05
# Train Epoch: 69 	Training Loss: 0.031208 	Validation Loss: 0.058300 	Counter: 06
# Train Epoch: 70 	Training Loss: 0.024008 	Validation Loss: 0.061484 	Counter: 07
# Train Epoch: 71 	Training Loss: 0.021910 	Validation Loss: 0.051504 	Counter: 08
# Train Epoch: 72 	Training Loss: 0.031863 	Validation Loss: 0.075677 	Counter: 09
# Train Epoch: 73 	Training Loss: 0.033122 	Validation Loss: 0.055893 	Counter: 10
# Train Epoch: 74 	Training Loss: 0.024034 	Validation Loss: 0.050316 	Counter: 11
# Train Epoch: 75 	Training Loss: 0.018503 	Validation Loss: 0.048253 	Counter: 00
# Train Epoch: 76 	Training Loss: 0.018273 	Validation Loss: 0.050114 	Counter: 01
# Train Epoch: 77 	Training Loss: 0.017422 	Validation Loss: 0.049124 	Counter: 02
# Train Epoch: 78 	Training Loss: 0.017615 	Validation Loss: 0.058711 	Counter: 03
# Train Epoch: 79 	Training Loss: 0.032188 	Validation Loss: 0.101214 	Counter: 04
# Train Epoch: 80 	Training Loss: 0.026331 	Validation Loss: 0.051247 	Counter: 05
# Train Epoch: 81 	Training Loss: 0.020315 	Validation Loss: 0.051664 	Counter: 06
# Train Epoch: 82 	Training Loss: 0.018964 	Validation Loss: 0.049842 	Counter: 07
# Train Epoch: 83 	Training Loss: 0.026513 	Validation Loss: 0.061063 	Counter: 08
# Train Epoch: 84 	Training Loss: 0.021193 	Validation Loss: 0.051421 	Counter: 09
# Train Epoch: 85 	Training Loss: 0.020898 	Validation Loss: 0.065452 	Counter: 10
# Train Epoch: 86 	Training Loss: 0.022363 	Validation Loss: 0.048295 	Counter: 11
# Train Epoch: 87 	Training Loss: 0.016471 	Validation Loss: 0.052356 	Counter: 12
# Train Epoch: 88 	Training Loss: 0.016274 	Validation Loss: 0.047415 	Counter: 13
# Train Epoch: 89 	Training Loss: 0.016368 	Validation Loss: 0.047719 	Counter: 14
# Train Epoch: 90 	Training Loss: 0.017516 	Validation Loss: 0.053168 	Counter: 15
# Train Epoch: 91 	Training Loss: 0.016095 	Validation Loss: 0.047652 	Counter: 16
# Train Epoch: 92 	Training Loss: 0.014991 	Validation Loss: 0.049297 	Counter: 17
# Train Epoch: 93 	Training Loss: 0.022357 	Validation Loss: 0.050196 	Counter: 18
# Train Epoch: 94 	Training Loss: 0.019932 	Validation Loss: 0.049759 	Counter: 19
# Train Epoch: 95 	Training Loss: 0.020220 	Validation Loss: 0.049184 	Counter: 20
# Train Epoch: 96 	Training Loss: 0.015912 	Validation Loss: 0.048967 	Counter: 21
# Train Epoch: 97 	Training Loss: 0.039695 	Validation Loss: 0.061092 	Counter: 22
# Train Epoch: 98 	Training Loss: 0.028905 	Validation Loss: 0.051894 	Counter: 23
# Train Epoch: 99 	Training Loss: 0.015710 	Validation Loss: 0.048715 	Counter: 24
# Train Epoch: 100 	Training Loss: 0.015513 	Validation Loss: 0.047637 	Counter: 25
# Train Epoch: 101 	Training Loss: 0.013251 	Validation Loss: 0.047778 	Counter: 26
# Train Epoch: 102 	Training Loss: 0.015001 	Validation Loss: 0.049937 	Counter: 27
# Train Epoch: 103 	Training Loss: 0.021648 	Validation Loss: 0.054054 	Counter: 28
# Train Epoch: 104 	Training Loss: 0.017802 	Validation Loss: 0.050233 	Counter: 29
# Train Epoch: 105 	Training Loss: 0.015873 	Validation Loss: 0.051239 	Counter: 30
# Training Done
#
# Training Time:  130.5807342529297
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avaa\avaa_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  avhh
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.0764691063196454, 1.7285090952650388, 0.10978666780879599, 6.079680258779019, 0.09464512743668484, 1.5090678198260505, -0.001704462533563421, 2.0279988686287913, 1.8929579892302133, 1.8169383427930208, 0.13570659145978226, 7.044638339768433, 0.05762771708348195, 1.5509233016798194]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.746711 	Validation Loss: 0.304544 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.350362 	Validation Loss: 0.198129 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.226189 	Validation Loss: 0.141789 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.196471 	Validation Loss: 0.141259 	Counter: 01
# Train Epoch: 05 	Training Loss: 0.160356 	Validation Loss: 0.118645 	Counter: 00
# Train Epoch: 06 	Training Loss: 0.141784 	Validation Loss: 0.132500 	Counter: 01
# Train Epoch: 07 	Training Loss: 0.120946 	Validation Loss: 0.097456 	Counter: 00
# Train Epoch: 08 	Training Loss: 0.114943 	Validation Loss: 0.099784 	Counter: 01
# Train Epoch: 09 	Training Loss: 0.119089 	Validation Loss: 0.104184 	Counter: 02
# Train Epoch: 10 	Training Loss: 0.111420 	Validation Loss: 0.091061 	Counter: 00
# Train Epoch: 11 	Training Loss: 0.093385 	Validation Loss: 0.111908 	Counter: 01
# Train Epoch: 12 	Training Loss: 0.093168 	Validation Loss: 0.086310 	Counter: 00
# Train Epoch: 13 	Training Loss: 0.095530 	Validation Loss: 0.099648 	Counter: 01
# Train Epoch: 14 	Training Loss: 0.091471 	Validation Loss: 0.105020 	Counter: 02
# Train Epoch: 15 	Training Loss: 0.075315 	Validation Loss: 0.083357 	Counter: 03
# Train Epoch: 16 	Training Loss: 0.089016 	Validation Loss: 0.085969 	Counter: 04
# Train Epoch: 17 	Training Loss: 0.066842 	Validation Loss: 0.078487 	Counter: 00
# Train Epoch: 18 	Training Loss: 0.060431 	Validation Loss: 0.080066 	Counter: 01
# Train Epoch: 19 	Training Loss: 0.058332 	Validation Loss: 0.076685 	Counter: 02
# Train Epoch: 20 	Training Loss: 0.080375 	Validation Loss: 0.105994 	Counter: 03
# Train Epoch: 21 	Training Loss: 0.062980 	Validation Loss: 0.075318 	Counter: 04
# Train Epoch: 22 	Training Loss: 0.050229 	Validation Loss: 0.076418 	Counter: 05
# Train Epoch: 23 	Training Loss: 0.053406 	Validation Loss: 0.075314 	Counter: 06
# Train Epoch: 24 	Training Loss: 0.061942 	Validation Loss: 0.086991 	Counter: 07
# Train Epoch: 25 	Training Loss: 0.057785 	Validation Loss: 0.077223 	Counter: 08
# Train Epoch: 26 	Training Loss: 0.049178 	Validation Loss: 0.075323 	Counter: 09
# Train Epoch: 27 	Training Loss: 0.041703 	Validation Loss: 0.078157 	Counter: 10
# Train Epoch: 28 	Training Loss: 0.046539 	Validation Loss: 0.111744 	Counter: 11
# Train Epoch: 29 	Training Loss: 0.055697 	Validation Loss: 0.099965 	Counter: 12
# Train Epoch: 30 	Training Loss: 0.043595 	Validation Loss: 0.080391 	Counter: 13
# Train Epoch: 31 	Training Loss: 0.041885 	Validation Loss: 0.072913 	Counter: 00
# Train Epoch: 32 	Training Loss: 0.051229 	Validation Loss: 0.087945 	Counter: 01
# Train Epoch: 33 	Training Loss: 0.045471 	Validation Loss: 0.075871 	Counter: 02
# Train Epoch: 34 	Training Loss: 0.034135 	Validation Loss: 0.078295 	Counter: 03
# Train Epoch: 35 	Training Loss: 0.038099 	Validation Loss: 0.078211 	Counter: 04
# Train Epoch: 36 	Training Loss: 0.036318 	Validation Loss: 0.075608 	Counter: 05
# Train Epoch: 37 	Training Loss: 0.045206 	Validation Loss: 0.081437 	Counter: 06
# Train Epoch: 38 	Training Loss: 0.049743 	Validation Loss: 0.092460 	Counter: 07
# Train Epoch: 39 	Training Loss: 0.073900 	Validation Loss: 0.082768 	Counter: 08
# Train Epoch: 40 	Training Loss: 0.038007 	Validation Loss: 0.079139 	Counter: 09
# Train Epoch: 41 	Training Loss: 0.039270 	Validation Loss: 0.081448 	Counter: 10
# Train Epoch: 42 	Training Loss: 0.029973 	Validation Loss: 0.076441 	Counter: 11
# Train Epoch: 43 	Training Loss: 0.027188 	Validation Loss: 0.076391 	Counter: 12
# Train Epoch: 44 	Training Loss: 0.025670 	Validation Loss: 0.076468 	Counter: 13
# Train Epoch: 45 	Training Loss: 0.075524 	Validation Loss: 0.163230 	Counter: 14
# Train Epoch: 46 	Training Loss: 0.067461 	Validation Loss: 0.086133 	Counter: 15
# Train Epoch: 47 	Training Loss: 0.038788 	Validation Loss: 0.085788 	Counter: 16
# Train Epoch: 48 	Training Loss: 0.030666 	Validation Loss: 0.079752 	Counter: 17
# Train Epoch: 49 	Training Loss: 0.027693 	Validation Loss: 0.082430 	Counter: 18
# Train Epoch: 50 	Training Loss: 0.030464 	Validation Loss: 0.088856 	Counter: 19
# Train Epoch: 51 	Training Loss: 0.030120 	Validation Loss: 0.081087 	Counter: 20
# Train Epoch: 52 	Training Loss: 0.026802 	Validation Loss: 0.080737 	Counter: 21
# Train Epoch: 53 	Training Loss: 0.022786 	Validation Loss: 0.086996 	Counter: 22
# Train Epoch: 54 	Training Loss: 0.023544 	Validation Loss: 0.080770 	Counter: 23
# Train Epoch: 55 	Training Loss: 0.021879 	Validation Loss: 0.080868 	Counter: 24
# Train Epoch: 56 	Training Loss: 0.022697 	Validation Loss: 0.081038 	Counter: 25
# Train Epoch: 57 	Training Loss: 0.028415 	Validation Loss: 0.084296 	Counter: 26
# Train Epoch: 58 	Training Loss: 0.025018 	Validation Loss: 0.084435 	Counter: 27
# Train Epoch: 59 	Training Loss: 0.040146 	Validation Loss: 0.091493 	Counter: 28
# Train Epoch: 60 	Training Loss: 0.030977 	Validation Loss: 0.079992 	Counter: 29
# Train Epoch: 61 	Training Loss: 0.022189 	Validation Loss: 0.085609 	Counter: 30
# Training Done
#
# Training Time:  74.09868788719177
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avhh\avhh_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  avpp
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.0744556541421413, 1.868901710102483, -0.06401552159636464, 7.460955991208158, 0.07560667179866483, 1.3339375265316695, -0.003202950070604782, 2.0197413643584126, 1.8715964511290861, 1.9633575411762838, 0.031162304524641422, 9.087467082710354, 0.07087459908727181, 1.4386129416539541]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.700125 	Validation Loss: 0.563056 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.326937 	Validation Loss: 0.291678 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.230469 	Validation Loss: 0.299778 	Counter: 01
# Train Epoch: 04 	Training Loss: 0.199429 	Validation Loss: 0.229332 	Counter: 00
# Train Epoch: 05 	Training Loss: 0.175007 	Validation Loss: 0.191467 	Counter: 00
# Train Epoch: 06 	Training Loss: 0.171751 	Validation Loss: 0.218831 	Counter: 01
# Train Epoch: 07 	Training Loss: 0.153990 	Validation Loss: 0.167983 	Counter: 00
# Train Epoch: 08 	Training Loss: 0.119363 	Validation Loss: 0.147327 	Counter: 00
# Train Epoch: 09 	Training Loss: 0.121696 	Validation Loss: 0.145123 	Counter: 01
# Train Epoch: 10 	Training Loss: 0.101861 	Validation Loss: 0.131128 	Counter: 00
# Train Epoch: 11 	Training Loss: 0.092086 	Validation Loss: 0.159977 	Counter: 01
# Train Epoch: 12 	Training Loss: 0.095586 	Validation Loss: 0.125722 	Counter: 02
# Train Epoch: 13 	Training Loss: 0.089671 	Validation Loss: 0.111192 	Counter: 00
# Train Epoch: 14 	Training Loss: 0.079548 	Validation Loss: 0.113193 	Counter: 01
# Train Epoch: 15 	Training Loss: 0.091632 	Validation Loss: 0.156867 	Counter: 02
# Train Epoch: 16 	Training Loss: 0.097999 	Validation Loss: 0.106902 	Counter: 03
# Train Epoch: 17 	Training Loss: 0.101214 	Validation Loss: 0.120284 	Counter: 04
# Train Epoch: 18 	Training Loss: 0.078405 	Validation Loss: 0.105877 	Counter: 05
# Train Epoch: 19 	Training Loss: 0.066445 	Validation Loss: 0.092323 	Counter: 00
# Train Epoch: 20 	Training Loss: 0.064265 	Validation Loss: 0.089658 	Counter: 01
# Train Epoch: 21 	Training Loss: 0.065534 	Validation Loss: 0.090530 	Counter: 02
# Train Epoch: 22 	Training Loss: 0.071842 	Validation Loss: 0.099355 	Counter: 03
# Train Epoch: 23 	Training Loss: 0.062155 	Validation Loss: 0.081489 	Counter: 00
# Train Epoch: 24 	Training Loss: 0.058085 	Validation Loss: 0.085967 	Counter: 01
# Train Epoch: 25 	Training Loss: 0.062859 	Validation Loss: 0.091073 	Counter: 02
# Train Epoch: 26 	Training Loss: 0.057775 	Validation Loss: 0.119029 	Counter: 03
# Train Epoch: 27 	Training Loss: 0.066537 	Validation Loss: 0.081360 	Counter: 04
# Train Epoch: 28 	Training Loss: 0.056986 	Validation Loss: 0.089077 	Counter: 05
# Train Epoch: 29 	Training Loss: 0.056554 	Validation Loss: 0.084821 	Counter: 06
# Train Epoch: 30 	Training Loss: 0.052268 	Validation Loss: 0.084082 	Counter: 07
# Train Epoch: 31 	Training Loss: 0.057156 	Validation Loss: 0.080820 	Counter: 08
# Train Epoch: 32 	Training Loss: 0.056229 	Validation Loss: 0.080217 	Counter: 09
# Train Epoch: 33 	Training Loss: 0.052671 	Validation Loss: 0.074440 	Counter: 00
# Train Epoch: 34 	Training Loss: 0.046678 	Validation Loss: 0.098007 	Counter: 01
# Train Epoch: 35 	Training Loss: 0.055707 	Validation Loss: 0.081218 	Counter: 02
# Train Epoch: 36 	Training Loss: 0.046372 	Validation Loss: 0.076775 	Counter: 03
# Train Epoch: 37 	Training Loss: 0.048257 	Validation Loss: 0.098028 	Counter: 04
# Train Epoch: 38 	Training Loss: 0.055549 	Validation Loss: 0.084100 	Counter: 05
# Train Epoch: 39 	Training Loss: 0.045093 	Validation Loss: 0.076767 	Counter: 06
# Train Epoch: 40 	Training Loss: 0.042339 	Validation Loss: 0.071005 	Counter: 07
# Train Epoch: 41 	Training Loss: 0.062527 	Validation Loss: 0.081897 	Counter: 08
# Train Epoch: 42 	Training Loss: 0.055049 	Validation Loss: 0.076284 	Counter: 09
# Train Epoch: 43 	Training Loss: 0.042056 	Validation Loss: 0.147455 	Counter: 10
# Train Epoch: 44 	Training Loss: 0.063421 	Validation Loss: 0.081211 	Counter: 11
# Train Epoch: 45 	Training Loss: 0.047283 	Validation Loss: 0.073072 	Counter: 12
# Train Epoch: 46 	Training Loss: 0.039329 	Validation Loss: 0.073240 	Counter: 13
# Train Epoch: 47 	Training Loss: 0.036768 	Validation Loss: 0.071138 	Counter: 14
# Train Epoch: 48 	Training Loss: 0.034539 	Validation Loss: 0.071393 	Counter: 15
# Train Epoch: 49 	Training Loss: 0.033257 	Validation Loss: 0.072716 	Counter: 16
# Train Epoch: 50 	Training Loss: 0.036693 	Validation Loss: 0.071223 	Counter: 17
# Train Epoch: 51 	Training Loss: 0.038116 	Validation Loss: 0.084800 	Counter: 18
# Train Epoch: 52 	Training Loss: 0.033629 	Validation Loss: 0.072367 	Counter: 19
# Train Epoch: 53 	Training Loss: 0.041614 	Validation Loss: 0.092142 	Counter: 20
# Train Epoch: 54 	Training Loss: 0.037200 	Validation Loss: 0.069326 	Counter: 00
# Train Epoch: 55 	Training Loss: 0.032865 	Validation Loss: 0.075402 	Counter: 01
# Train Epoch: 56 	Training Loss: 0.033331 	Validation Loss: 0.069826 	Counter: 02
# Train Epoch: 57 	Training Loss: 0.040534 	Validation Loss: 0.087587 	Counter: 03
# Train Epoch: 58 	Training Loss: 0.043204 	Validation Loss: 0.070514 	Counter: 04
# Train Epoch: 59 	Training Loss: 0.038178 	Validation Loss: 0.103520 	Counter: 05
# Train Epoch: 60 	Training Loss: 0.031451 	Validation Loss: 0.071909 	Counter: 06
# Train Epoch: 61 	Training Loss: 0.028442 	Validation Loss: 0.067642 	Counter: 07
# Train Epoch: 62 	Training Loss: 0.032374 	Validation Loss: 0.084375 	Counter: 08
# Train Epoch: 63 	Training Loss: 0.041352 	Validation Loss: 0.071390 	Counter: 09
# Train Epoch: 64 	Training Loss: 0.029156 	Validation Loss: 0.069722 	Counter: 10
# Train Epoch: 65 	Training Loss: 0.029162 	Validation Loss: 0.067672 	Counter: 11
# Train Epoch: 66 	Training Loss: 0.036558 	Validation Loss: 0.075828 	Counter: 12
# Train Epoch: 67 	Training Loss: 0.040167 	Validation Loss: 0.070728 	Counter: 13
# Train Epoch: 68 	Training Loss: 0.030731 	Validation Loss: 0.071333 	Counter: 14
# Train Epoch: 69 	Training Loss: 0.028058 	Validation Loss: 0.086288 	Counter: 15
# Train Epoch: 70 	Training Loss: 0.052890 	Validation Loss: 0.151443 	Counter: 16
# Train Epoch: 71 	Training Loss: 0.044290 	Validation Loss: 0.076948 	Counter: 17
# Train Epoch: 72 	Training Loss: 0.037420 	Validation Loss: 0.088117 	Counter: 18
# Train Epoch: 73 	Training Loss: 0.035329 	Validation Loss: 0.070160 	Counter: 19
# Train Epoch: 74 	Training Loss: 0.029383 	Validation Loss: 0.071162 	Counter: 20
# Train Epoch: 75 	Training Loss: 0.040567 	Validation Loss: 0.084668 	Counter: 21
# Train Epoch: 76 	Training Loss: 0.030578 	Validation Loss: 0.068964 	Counter: 22
# Train Epoch: 77 	Training Loss: 0.023569 	Validation Loss: 0.068606 	Counter: 23
# Train Epoch: 78 	Training Loss: 0.031847 	Validation Loss: 0.079429 	Counter: 24
# Train Epoch: 79 	Training Loss: 0.029813 	Validation Loss: 0.070572 	Counter: 25
# Train Epoch: 80 	Training Loss: 0.021825 	Validation Loss: 0.069059 	Counter: 26
# Train Epoch: 81 	Training Loss: 0.019608 	Validation Loss: 0.070239 	Counter: 27
# Train Epoch: 82 	Training Loss: 0.020194 	Validation Loss: 0.071393 	Counter: 28
# Train Epoch: 83 	Training Loss: 0.032560 	Validation Loss: 0.074637 	Counter: 29
# Train Epoch: 84 	Training Loss: 0.038569 	Validation Loss: 0.122601 	Counter: 30
# Training Done
#
# Training Time:  98.61125707626343
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avpp\avpp_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  avs
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.0682973728620375, 1.7602535863767557, 0.04310871415942189, 7.7077614693460825, 0.06297572344581434, 1.5147685154163786, -0.004706254623571982, 2.0101418620921176, 1.880579180236584, 1.7938972036820084, -0.13626812871268312, 9.504542010885496, 0.08320254390204002, 1.6237502449679637]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.725542 	Validation Loss: 0.493789 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.449416 	Validation Loss: 0.352817 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.270431 	Validation Loss: 0.245177 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.228716 	Validation Loss: 0.232725 	Counter: 00
# Train Epoch: 05 	Training Loss: 0.186505 	Validation Loss: 0.202228 	Counter: 00
# Train Epoch: 06 	Training Loss: 0.159814 	Validation Loss: 0.149168 	Counter: 00
# Train Epoch: 07 	Training Loss: 0.139435 	Validation Loss: 0.168781 	Counter: 01
# Train Epoch: 08 	Training Loss: 0.146386 	Validation Loss: 0.133955 	Counter: 00
# Train Epoch: 09 	Training Loss: 0.115419 	Validation Loss: 0.122535 	Counter: 00
# Train Epoch: 10 	Training Loss: 0.108078 	Validation Loss: 0.119264 	Counter: 01
# Train Epoch: 11 	Training Loss: 0.099214 	Validation Loss: 0.123717 	Counter: 02
# Train Epoch: 12 	Training Loss: 0.087701 	Validation Loss: 0.098005 	Counter: 00
# Train Epoch: 13 	Training Loss: 0.083698 	Validation Loss: 0.119940 	Counter: 01
# Train Epoch: 14 	Training Loss: 0.080257 	Validation Loss: 0.089999 	Counter: 00
# Train Epoch: 15 	Training Loss: 0.074970 	Validation Loss: 0.136993 	Counter: 01
# Train Epoch: 16 	Training Loss: 0.093867 	Validation Loss: 0.081822 	Counter: 00
# Train Epoch: 17 	Training Loss: 0.075473 	Validation Loss: 0.074288 	Counter: 00
# Train Epoch: 18 	Training Loss: 0.065695 	Validation Loss: 0.077700 	Counter: 01
# Train Epoch: 19 	Training Loss: 0.084639 	Validation Loss: 0.107728 	Counter: 02
# Train Epoch: 20 	Training Loss: 0.071170 	Validation Loss: 0.081239 	Counter: 03
# Train Epoch: 21 	Training Loss: 0.061226 	Validation Loss: 0.083719 	Counter: 04
# Train Epoch: 22 	Training Loss: 0.058264 	Validation Loss: 0.069662 	Counter: 00
# Train Epoch: 23 	Training Loss: 0.055544 	Validation Loss: 0.085658 	Counter: 01
# Train Epoch: 24 	Training Loss: 0.060916 	Validation Loss: 0.071642 	Counter: 02
# Train Epoch: 25 	Training Loss: 0.066723 	Validation Loss: 0.067081 	Counter: 03
# Train Epoch: 26 	Training Loss: 0.057950 	Validation Loss: 0.067637 	Counter: 04
# Train Epoch: 27 	Training Loss: 0.051353 	Validation Loss: 0.063037 	Counter: 00
# Train Epoch: 28 	Training Loss: 0.047351 	Validation Loss: 0.062194 	Counter: 01
# Train Epoch: 29 	Training Loss: 0.053145 	Validation Loss: 0.071934 	Counter: 02
# Train Epoch: 30 	Training Loss: 0.051626 	Validation Loss: 0.061585 	Counter: 03
# Train Epoch: 31 	Training Loss: 0.045665 	Validation Loss: 0.072347 	Counter: 04
# Train Epoch: 32 	Training Loss: 0.053359 	Validation Loss: 0.073996 	Counter: 05
# Train Epoch: 33 	Training Loss: 0.055064 	Validation Loss: 0.068575 	Counter: 06
# Train Epoch: 34 	Training Loss: 0.045484 	Validation Loss: 0.065258 	Counter: 07
# Train Epoch: 35 	Training Loss: 0.053104 	Validation Loss: 0.082314 	Counter: 08
# Train Epoch: 36 	Training Loss: 0.051207 	Validation Loss: 0.083255 	Counter: 09
# Train Epoch: 37 	Training Loss: 0.044061 	Validation Loss: 0.057863 	Counter: 00
# Train Epoch: 38 	Training Loss: 0.046821 	Validation Loss: 0.171653 	Counter: 01
# Train Epoch: 39 	Training Loss: 0.060522 	Validation Loss: 0.078615 	Counter: 02
# Train Epoch: 40 	Training Loss: 0.081884 	Validation Loss: 0.085510 	Counter: 03
# Train Epoch: 41 	Training Loss: 0.046453 	Validation Loss: 0.061501 	Counter: 04
# Train Epoch: 42 	Training Loss: 0.040699 	Validation Loss: 0.062541 	Counter: 05
# Train Epoch: 43 	Training Loss: 0.037547 	Validation Loss: 0.058605 	Counter: 06
# Train Epoch: 44 	Training Loss: 0.037434 	Validation Loss: 0.064592 	Counter: 07
# Train Epoch: 45 	Training Loss: 0.034838 	Validation Loss: 0.059212 	Counter: 08
# Train Epoch: 46 	Training Loss: 0.035332 	Validation Loss: 0.073670 	Counter: 09
# Train Epoch: 47 	Training Loss: 0.040307 	Validation Loss: 0.070382 	Counter: 10
# Train Epoch: 48 	Training Loss: 0.053056 	Validation Loss: 0.081346 	Counter: 11
# Train Epoch: 49 	Training Loss: 0.046959 	Validation Loss: 0.073884 	Counter: 12
# Train Epoch: 50 	Training Loss: 0.035251 	Validation Loss: 0.062680 	Counter: 13
# Train Epoch: 51 	Training Loss: 0.031235 	Validation Loss: 0.056350 	Counter: 14
# Train Epoch: 52 	Training Loss: 0.027711 	Validation Loss: 0.056336 	Counter: 15
# Train Epoch: 53 	Training Loss: 0.027651 	Validation Loss: 0.056871 	Counter: 16
# Train Epoch: 54 	Training Loss: 0.035232 	Validation Loss: 0.076778 	Counter: 17
# Train Epoch: 55 	Training Loss: 0.045452 	Validation Loss: 0.064931 	Counter: 18
# Train Epoch: 56 	Training Loss: 0.037782 	Validation Loss: 0.056638 	Counter: 19
# Train Epoch: 57 	Training Loss: 0.037356 	Validation Loss: 0.112016 	Counter: 20
# Train Epoch: 58 	Training Loss: 0.040006 	Validation Loss: 0.061007 	Counter: 21
# Train Epoch: 59 	Training Loss: 0.026645 	Validation Loss: 0.062609 	Counter: 22
# Train Epoch: 60 	Training Loss: 0.027148 	Validation Loss: 0.063853 	Counter: 23
# Train Epoch: 61 	Training Loss: 0.027802 	Validation Loss: 0.059035 	Counter: 24
# Train Epoch: 62 	Training Loss: 0.025494 	Validation Loss: 0.091879 	Counter: 25
# Train Epoch: 63 	Training Loss: 0.046942 	Validation Loss: 0.063311 	Counter: 26
# Train Epoch: 64 	Training Loss: 0.032616 	Validation Loss: 0.059885 	Counter: 27
# Train Epoch: 65 	Training Loss: 0.039065 	Validation Loss: 0.063955 	Counter: 28
# Train Epoch: 66 	Training Loss: 0.025904 	Validation Loss: 0.057033 	Counter: 29
# Train Epoch: 67 	Training Loss: 0.027499 	Validation Loss: 0.058729 	Counter: 30
# Training Done
#
# Training Time:  85.31732964515686
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avs\avs_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  hhvaa
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.0802834116423705, 1.8643407255946491, 0.13957244700478932, 5.511271255389008, -0.037782807979156195, 1.5008100793566927, -0.004192361121149529, 2.111915823385521, 1.8892015251695822, 1.8854664221303954, -0.07014244892609894, 7.868853952552248, 0.04091299370473708, 2.067578946017368]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.527185 	Validation Loss: 0.360836 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.159974 	Validation Loss: 0.241092 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.114102 	Validation Loss: 0.176509 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.096550 	Validation Loss: 0.157875 	Counter: 00
# Train Epoch: 05 	Training Loss: 0.082215 	Validation Loss: 0.143721 	Counter: 00
# Train Epoch: 06 	Training Loss: 0.078974 	Validation Loss: 0.120698 	Counter: 00
# Train Epoch: 07 	Training Loss: 0.069546 	Validation Loss: 0.105633 	Counter: 00
# Train Epoch: 08 	Training Loss: 0.062092 	Validation Loss: 0.115923 	Counter: 01
# Train Epoch: 09 	Training Loss: 0.061395 	Validation Loss: 0.105910 	Counter: 02
# Train Epoch: 10 	Training Loss: 0.063672 	Validation Loss: 0.110828 	Counter: 03
# Train Epoch: 11 	Training Loss: 0.057854 	Validation Loss: 0.106751 	Counter: 04
# Train Epoch: 12 	Training Loss: 0.051871 	Validation Loss: 0.096850 	Counter: 00
# Train Epoch: 13 	Training Loss: 0.051873 	Validation Loss: 0.096352 	Counter: 01
# Train Epoch: 14 	Training Loss: 0.046795 	Validation Loss: 0.097823 	Counter: 02
# Train Epoch: 15 	Training Loss: 0.045483 	Validation Loss: 0.090680 	Counter: 00
# Train Epoch: 16 	Training Loss: 0.041237 	Validation Loss: 0.091575 	Counter: 01
# Train Epoch: 17 	Training Loss: 0.041447 	Validation Loss: 0.095454 	Counter: 02
# Train Epoch: 18 	Training Loss: 0.039194 	Validation Loss: 0.082859 	Counter: 00
# Train Epoch: 19 	Training Loss: 0.035637 	Validation Loss: 0.079564 	Counter: 01
# Train Epoch: 20 	Training Loss: 0.034962 	Validation Loss: 0.076474 	Counter: 00
# Train Epoch: 21 	Training Loss: 0.032645 	Validation Loss: 0.078922 	Counter: 01
# Train Epoch: 22 	Training Loss: 0.032376 	Validation Loss: 0.083771 	Counter: 02
# Train Epoch: 23 	Training Loss: 0.031103 	Validation Loss: 0.078086 	Counter: 03
# Train Epoch: 24 	Training Loss: 0.029166 	Validation Loss: 0.074423 	Counter: 04
# Train Epoch: 25 	Training Loss: 0.028120 	Validation Loss: 0.080645 	Counter: 05
# Train Epoch: 26 	Training Loss: 0.028924 	Validation Loss: 0.073201 	Counter: 06
# Train Epoch: 27 	Training Loss: 0.025530 	Validation Loss: 0.074942 	Counter: 07
# Train Epoch: 28 	Training Loss: 0.024574 	Validation Loss: 0.077476 	Counter: 08
# Train Epoch: 29 	Training Loss: 0.024724 	Validation Loss: 0.073384 	Counter: 09
# Train Epoch: 30 	Training Loss: 0.024260 	Validation Loss: 0.084090 	Counter: 10
# Train Epoch: 31 	Training Loss: 0.024741 	Validation Loss: 0.088044 	Counter: 11
# Train Epoch: 32 	Training Loss: 0.023012 	Validation Loss: 0.085158 	Counter: 12
# Train Epoch: 33 	Training Loss: 0.023953 	Validation Loss: 0.076912 	Counter: 13
# Train Epoch: 34 	Training Loss: 0.021923 	Validation Loss: 0.077787 	Counter: 14
# Train Epoch: 35 	Training Loss: 0.022126 	Validation Loss: 0.075634 	Counter: 15
# Train Epoch: 36 	Training Loss: 0.021761 	Validation Loss: 0.071773 	Counter: 00
# Train Epoch: 37 	Training Loss: 0.020494 	Validation Loss: 0.085034 	Counter: 01
# Train Epoch: 38 	Training Loss: 0.021500 	Validation Loss: 0.071490 	Counter: 02
# Train Epoch: 39 	Training Loss: 0.019749 	Validation Loss: 0.072715 	Counter: 03
# Train Epoch: 40 	Training Loss: 0.020261 	Validation Loss: 0.086955 	Counter: 04
# Train Epoch: 41 	Training Loss: 0.021351 	Validation Loss: 0.081399 	Counter: 05
# Train Epoch: 42 	Training Loss: 0.019254 	Validation Loss: 0.072136 	Counter: 06
# Train Epoch: 43 	Training Loss: 0.018187 	Validation Loss: 0.082106 	Counter: 07
# Train Epoch: 44 	Training Loss: 0.018394 	Validation Loss: 0.078650 	Counter: 08
# Train Epoch: 45 	Training Loss: 0.019301 	Validation Loss: 0.078017 	Counter: 09
# Train Epoch: 46 	Training Loss: 0.025832 	Validation Loss: 0.081819 	Counter: 10
# Train Epoch: 47 	Training Loss: 0.022651 	Validation Loss: 0.080476 	Counter: 11
# Train Epoch: 48 	Training Loss: 0.018225 	Validation Loss: 0.081728 	Counter: 12
# Train Epoch: 49 	Training Loss: 0.015522 	Validation Loss: 0.075251 	Counter: 13
# Train Epoch: 50 	Training Loss: 0.016566 	Validation Loss: 0.074320 	Counter: 14
# Train Epoch: 51 	Training Loss: 0.016255 	Validation Loss: 0.074555 	Counter: 15
# Train Epoch: 52 	Training Loss: 0.016326 	Validation Loss: 0.073051 	Counter: 16
# Train Epoch: 53 	Training Loss: 0.017018 	Validation Loss: 0.070980 	Counter: 17
# Train Epoch: 54 	Training Loss: 0.014904 	Validation Loss: 0.077211 	Counter: 18
# Train Epoch: 55 	Training Loss: 0.014966 	Validation Loss: 0.083952 	Counter: 19
# Train Epoch: 56 	Training Loss: 0.015773 	Validation Loss: 0.077420 	Counter: 20
# Train Epoch: 57 	Training Loss: 0.014050 	Validation Loss: 0.081407 	Counter: 21
# Train Epoch: 58 	Training Loss: 0.014549 	Validation Loss: 0.078202 	Counter: 22
# Train Epoch: 59 	Training Loss: 0.014288 	Validation Loss: 0.075127 	Counter: 23
# Train Epoch: 60 	Training Loss: 0.014045 	Validation Loss: 0.079620 	Counter: 24
# Train Epoch: 61 	Training Loss: 0.013134 	Validation Loss: 0.077093 	Counter: 25
# Train Epoch: 62 	Training Loss: 0.012957 	Validation Loss: 0.081124 	Counter: 26
# Train Epoch: 63 	Training Loss: 0.013723 	Validation Loss: 0.076300 	Counter: 27
# Train Epoch: 64 	Training Loss: 0.012505 	Validation Loss: 0.080674 	Counter: 28
# Train Epoch: 65 	Training Loss: 0.014127 	Validation Loss: 0.080598 	Counter: 29
# Train Epoch: 66 	Training Loss: 0.014514 	Validation Loss: 0.081518 	Counter: 30
# Training Done
#
# Training Time:  75.40681195259094
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvaa\hhvaa_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  hhvpp
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.0775723286176344, 1.8855570439011582, 0.18993259965292275, 5.879656135979334, -0.0484930880325692, 1.3884972710628973, -0.0047390443704359055, 2.0931812551302635, 1.8838020852909008, 1.9178660989045544, -0.054499292520250694, 7.694298502515478, 0.04238329291453696, 2.0070186420650136]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.455541 	Validation Loss: 0.138318 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.096098 	Validation Loss: 0.074444 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.062327 	Validation Loss: 0.057625 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.049933 	Validation Loss: 0.056549 	Counter: 01
# Train Epoch: 05 	Training Loss: 0.043194 	Validation Loss: 0.047080 	Counter: 00
# Train Epoch: 06 	Training Loss: 0.037740 	Validation Loss: 0.044364 	Counter: 00
# Train Epoch: 07 	Training Loss: 0.033577 	Validation Loss: 0.039301 	Counter: 00
# Train Epoch: 08 	Training Loss: 0.031276 	Validation Loss: 0.036069 	Counter: 00
# Train Epoch: 09 	Training Loss: 0.028674 	Validation Loss: 0.038183 	Counter: 01
# Train Epoch: 10 	Training Loss: 0.027973 	Validation Loss: 0.034853 	Counter: 02
# Train Epoch: 11 	Training Loss: 0.025567 	Validation Loss: 0.032193 	Counter: 00
# Train Epoch: 12 	Training Loss: 0.024799 	Validation Loss: 0.030955 	Counter: 01
# Train Epoch: 13 	Training Loss: 0.023817 	Validation Loss: 0.034935 	Counter: 02
# Train Epoch: 14 	Training Loss: 0.022811 	Validation Loss: 0.034255 	Counter: 03
# Train Epoch: 15 	Training Loss: 0.021136 	Validation Loss: 0.043020 	Counter: 04
# Train Epoch: 16 	Training Loss: 0.021175 	Validation Loss: 0.040315 	Counter: 05
# Train Epoch: 17 	Training Loss: 0.022576 	Validation Loss: 0.034037 	Counter: 06
# Train Epoch: 18 	Training Loss: 0.019536 	Validation Loss: 0.028941 	Counter: 00
# Train Epoch: 19 	Training Loss: 0.016917 	Validation Loss: 0.027610 	Counter: 01
# Train Epoch: 20 	Training Loss: 0.016471 	Validation Loss: 0.025683 	Counter: 00
# Train Epoch: 21 	Training Loss: 0.015588 	Validation Loss: 0.028419 	Counter: 01
# Train Epoch: 22 	Training Loss: 0.014521 	Validation Loss: 0.024145 	Counter: 00
# Train Epoch: 23 	Training Loss: 0.014729 	Validation Loss: 0.021975 	Counter: 00
# Train Epoch: 24 	Training Loss: 0.012590 	Validation Loss: 0.022728 	Counter: 01
# Train Epoch: 25 	Training Loss: 0.012351 	Validation Loss: 0.023428 	Counter: 02
# Train Epoch: 26 	Training Loss: 0.012064 	Validation Loss: 0.021487 	Counter: 03
# Train Epoch: 27 	Training Loss: 0.010706 	Validation Loss: 0.019576 	Counter: 00
# Train Epoch: 28 	Training Loss: 0.011417 	Validation Loss: 0.019963 	Counter: 01
# Train Epoch: 29 	Training Loss: 0.010826 	Validation Loss: 0.021126 	Counter: 02
# Train Epoch: 30 	Training Loss: 0.010431 	Validation Loss: 0.019269 	Counter: 03
# Train Epoch: 31 	Training Loss: 0.009710 	Validation Loss: 0.019337 	Counter: 04
# Train Epoch: 32 	Training Loss: 0.010158 	Validation Loss: 0.019174 	Counter: 05
# Train Epoch: 33 	Training Loss: 0.009892 	Validation Loss: 0.021560 	Counter: 06
# Train Epoch: 34 	Training Loss: 0.009241 	Validation Loss: 0.022190 	Counter: 07
# Train Epoch: 35 	Training Loss: 0.008605 	Validation Loss: 0.020648 	Counter: 08
# Train Epoch: 36 	Training Loss: 0.008661 	Validation Loss: 0.023064 	Counter: 09
# Train Epoch: 37 	Training Loss: 0.008591 	Validation Loss: 0.017724 	Counter: 00
# ...
# Train Epoch: 117 	Training Loss: 0.004004 	Validation Loss: 0.022461 	Counter: 23
# Train Epoch: 118 	Training Loss: 0.003628 	Validation Loss: 0.022934 	Counter: 24
# Train Epoch: 119 	Training Loss: 0.003529 	Validation Loss: 0.023903 	Counter: 25
# Train Epoch: 120 	Training Loss: 0.003562 	Validation Loss: 0.023183 	Counter: 26
# Train Epoch: 121 	Training Loss: 0.003726 	Validation Loss: 0.026402 	Counter: 27
# Train Epoch: 122 	Training Loss: 0.004273 	Validation Loss: 0.022983 	Counter: 28
# Train Epoch: 123 	Training Loss: 0.006877 	Validation Loss: 0.026613 	Counter: 29
# Train Epoch: 124 	Training Loss: 0.004635 	Validation Loss: 0.021321 	Counter: 30
# Training Done
#
# Training Time:  177.035160779953
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvpp\pvpp_BiMod_5_LSTM_v1 .pickle
# EXPERIMENT:  pvs
# Cuda available: True
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# Std_factors:  [2.089979554540331, 1.7291221744507224, 0.15287192323268203, 5.266335223103865, -0.05360388430924514, 1.4175416722390526, -0.0033323455197209577, 2.008585584973679, 1.8838231189277788, 1.799004939026661, 0.09085089021094431, 7.377129217324501, 0.033808888042636126, 2.1118156922521374]
# No of train realizations:  5
# No of val realizations:  1
# No of test realizations:  81
# No of realizations:  87
# Train batch size:  1
#
#  Beginning Training
# Train Epoch: 01 	Training Loss: 0.531238 	Validation Loss: 0.293193 	Counter: 00
# Train Epoch: 02 	Training Loss: 0.165700 	Validation Loss: 0.157344 	Counter: 00
# Train Epoch: 03 	Training Loss: 0.113302 	Validation Loss: 0.133164 	Counter: 00
# Train Epoch: 04 	Training Loss: 0.096627 	Validation Loss: 0.111633 	Counter: 00
# Train Epoch: 05 	Training Loss: 0.085110 	Validation Loss: 0.109891 	Counter: 01
# Train Epoch: 06 	Training Loss: 0.080786 	Validation Loss: 0.092550 	Counter: 00
# Train Epoch: 07 	Training Loss: 0.068640 	Validation Loss: 0.088383 	Counter: 01
# Train Epoch: 08 	Training Loss: 0.061573 	Validation Loss: 0.085681 	Counter: 00
# Train Epoch: 09 	Training Loss: 0.051516 	Validation Loss: 0.070853 	Counter: 00
# Train Epoch: 10 	Training Loss: 0.044977 	Validation Loss: 0.063734 	Counter: 00
# Train Epoch: 11 	Training Loss: 0.044932 	Validation Loss: 0.093463 	Counter: 01
# Train Epoch: 12 	Training Loss: 0.040825 	Validation Loss: 0.062045 	Counter: 02
# Train Epoch: 13 	Training Loss: 0.035365 	Validation Loss: 0.056498 	Counter: 00
# Train Epoch: 14 	Training Loss: 0.034867 	Validation Loss: 0.067212 	Counter: 01
# Train Epoch: 15 	Training Loss: 0.036371 	Validation Loss: 0.055335 	Counter: 02
# Train Epoch: 16 	Training Loss: 0.030075 	Validation Loss: 0.067692 	Counter: 03
# Train Epoch: 17 	Training Loss: 0.032561 	Validation Loss: 0.055151 	Counter: 04
# Train Epoch: 18 	Training Loss: 0.029325 	Validation Loss: 0.049196 	Counter: 00
# Train Epoch: 19 	Training Loss: 0.026119 	Validation Loss: 0.048146 	Counter: 01
# Train Epoch: 20 	Training Loss: 0.024010 	Validation Loss: 0.044439 	Counter: 00
# Train Epoch: 21 	Training Loss: 0.022072 	Validation Loss: 0.044325 	Counter: 01
# Train Epoch: 22 	Training Loss: 0.020807 	Validation Loss: 0.045468 	Counter: 02
# Train Epoch: 23 	Training Loss: 0.022746 	Validation Loss: 0.053412 	Counter: 03
# Train Epoch: 24 	Training Loss: 0.039372 	Validation Loss: 0.056085 	Counter: 04
# Train Epoch: 25 	Training Loss: 0.022688 	Validation Loss: 0.049039 	Counter: 05
# Train Epoch: 26 	Training Loss: 0.020763 	Validation Loss: 0.051873 	Counter: 06
# Train Epoch: 27 	Training Loss: 0.020880 	Validation Loss: 0.061001 	Counter: 07
# Train Epoch: 28 	Training Loss: 0.019181 	Validation Loss: 0.044001 	Counter: 08
# Train Epoch: 29 	Training Loss: 0.016773 	Validation Loss: 0.049470 	Counter: 09
# Train Epoch: 30 	Training Loss: 0.018598 	Validation Loss: 0.053587 	Counter: 10
# Train Epoch: 31 	Training Loss: 0.018829 	Validation Loss: 0.048761 	Counter: 11
# Train Epoch: 32 	Training Loss: 0.016546 	Validation Loss: 0.042973 	Counter: 12
# Train Epoch: 33 	Training Loss: 0.016708 	Validation Loss: 0.043935 	Counter: 13
# Train Epoch: 34 	Training Loss: 0.020858 	Validation Loss: 0.049944 	Counter: 14
# Train Epoch: 35 	Training Loss: 0.016526 	Validation Loss: 0.042968 	Counter: 15
# Train Epoch: 36 	Training Loss: 0.013629 	Validation Loss: 0.039412 	Counter: 00
# Train Epoch: 37 	Training Loss: 0.012866 	Validation Loss: 0.038248 	Counter: 01
# Train Epoch: 38 	Training Loss: 0.012421 	Validation Loss: 0.040081 	Counter: 02
# Train Epoch: 39 	Training Loss: 0.019996 	Validation Loss: 0.046339 	Counter: 03
# Train Epoch: 40 	Training Loss: 0.014968 	Validation Loss: 0.037909 	Counter: 04
# Train Epoch: 41 	Training Loss: 0.012875 	Validation Loss: 0.040131 	Counter: 05
# Train Epoch: 42 	Training Loss: 0.015081 	Validation Loss: 0.040107 	Counter: 06
# Train Epoch: 43 	Training Loss: 0.013420 	Validation Loss: 0.042058 	Counter: 07
# Train Epoch: 44 	Training Loss: 0.018059 	Validation Loss: 0.050547 	Counter: 08
# Train Epoch: 45 	Training Loss: 0.015404 	Validation Loss: 0.040402 	Counter: 09
# Train Epoch: 46 	Training Loss: 0.011853 	Validation Loss: 0.039354 	Counter: 10
# Train Epoch: 47 	Training Loss: 0.011861 	Validation Loss: 0.039449 	Counter: 11
# Train Epoch: 48 	Training Loss: 0.011773 	Validation Loss: 0.039879 	Counter: 12
# Train Epoch: 49 	Training Loss: 0.011526 	Validation Loss: 0.034656 	Counter: 00
# Train Epoch: 50 	Training Loss: 0.010402 	Validation Loss: 0.035938 	Counter: 01
# Train Epoch: 51 	Training Loss: 0.011257 	Validation Loss: 0.038722 	Counter: 02
# Train Epoch: 52 	Training Loss: 0.013312 	Validation Loss: 0.047434 	Counter: 03
# Train Epoch: 53 	Training Loss: 0.017519 	Validation Loss: 0.044245 	Counter: 04
# Train Epoch: 54 	Training Loss: 0.011237 	Validation Loss: 0.036371 	Counter: 05
# Train Epoch: 55 	Training Loss: 0.010814 	Validation Loss: 0.035287 	Counter: 06
# Train Epoch: 56 	Training Loss: 0.013505 	Validation Loss: 0.035987 	Counter: 07
# Train Epoch: 57 	Training Loss: 0.009770 	Validation Loss: 0.034384 	Counter: 08
# Train Epoch: 58 	Training Loss: 0.008784 	Validation Loss: 0.033702 	Counter: 09
# Train Epoch: 59 	Training Loss: 0.009808 	Validation Loss: 0.035475 	Counter: 10
# Train Epoch: 60 	Training Loss: 0.009590 	Validation Loss: 0.035337 	Counter: 11
# Train Epoch: 61 	Training Loss: 0.009996 	Validation Loss: 0.034403 	Counter: 12
# Train Epoch: 62 	Training Loss: 0.008933 	Validation Loss: 0.034642 	Counter: 13
# Train Epoch: 63 	Training Loss: 0.010863 	Validation Loss: 0.039056 	Counter: 14
# Train Epoch: 64 	Training Loss: 0.011967 	Validation Loss: 0.036076 	Counter: 15
# Train Epoch: 65 	Training Loss: 0.009051 	Validation Loss: 0.036978 	Counter: 16
# Train Epoch: 66 	Training Loss: 0.010805 	Validation Loss: 0.037794 	Counter: 17
# Train Epoch: 67 	Training Loss: 0.009418 	Validation Loss: 0.035573 	Counter: 18
# Train Epoch: 68 	Training Loss: 0.009034 	Validation Loss: 0.037034 	Counter: 19
# Train Epoch: 69 	Training Loss: 0.008387 	Validation Loss: 0.032552 	Counter: 00
# Train Epoch: 70 	Training Loss: 0.007759 	Validation Loss: 0.033853 	Counter: 01
# Train Epoch: 71 	Training Loss: 0.016271 	Validation Loss: 0.044268 	Counter: 02
# Train Epoch: 72 	Training Loss: 0.018466 	Validation Loss: 0.040935 	Counter: 03
# Train Epoch: 73 	Training Loss: 0.011154 	Validation Loss: 0.034343 	Counter: 04
# Train Epoch: 74 	Training Loss: 0.008322 	Validation Loss: 0.033315 	Counter: 05
# Train Epoch: 75 	Training Loss: 0.007268 	Validation Loss: 0.034514 	Counter: 06
# Train Epoch: 76 	Training Loss: 0.007732 	Validation Loss: 0.036567 	Counter: 07
# Train Epoch: 77 	Training Loss: 0.007118 	Validation Loss: 0.032462 	Counter: 08
# Train Epoch: 78 	Training Loss: 0.007210 	Validation Loss: 0.030652 	Counter: 00
# Train Epoch: 79 	Training Loss: 0.008029 	Validation Loss: 0.034519 	Counter: 01
# Train Epoch: 80 	Training Loss: 0.010454 	Validation Loss: 0.032843 	Counter: 02
# Train Epoch: 81 	Training Loss: 0.006935 	Validation Loss: 0.032349 	Counter: 03
# Train Epoch: 82 	Training Loss: 0.009633 	Validation Loss: 0.039703 	Counter: 04
# Train Epoch: 83 	Training Loss: 0.009720 	Validation Loss: 0.036380 	Counter: 05
# Train Epoch: 84 	Training Loss: 0.008263 	Validation Loss: 0.031777 	Counter: 06
# Train Epoch: 85 	Training Loss: 0.007494 	Validation Loss: 0.030954 	Counter: 07
# Train Epoch: 86 	Training Loss: 0.006286 	Validation Loss: 0.031127 	Counter: 08
# Train Epoch: 87 	Training Loss: 0.006464 	Validation Loss: 0.032063 	Counter: 09
# Train Epoch: 88 	Training Loss: 0.007390 	Validation Loss: 0.033292 	Counter: 10
# Train Epoch: 89 	Training Loss: 0.011677 	Validation Loss: 0.034706 	Counter: 11
# Train Epoch: 90 	Training Loss: 0.013132 	Validation Loss: 0.038008 	Counter: 12
# Train Epoch: 91 	Training Loss: 0.011194 	Validation Loss: 0.041608 	Counter: 13
# Train Epoch: 92 	Training Loss: 0.008538 	Validation Loss: 0.032650 	Counter: 14
# Train Epoch: 93 	Training Loss: 0.006819 	Validation Loss: 0.030972 	Counter: 15
# Train Epoch: 94 	Training Loss: 0.006702 	Validation Loss: 0.031629 	Counter: 16
# Train Epoch: 95 	Training Loss: 0.006379 	Validation Loss: 0.031085 	Counter: 17
# Train Epoch: 96 	Training Loss: 0.006661 	Validation Loss: 0.036227 	Counter: 18
# Train Epoch: 97 	Training Loss: 0.008743 	Validation Loss: 0.033672 	Counter: 19
# Train Epoch: 98 	Training Loss: 0.007962 	Validation Loss: 0.032495 	Counter: 20
# Train Epoch: 99 	Training Loss: 0.008291 	Validation Loss: 0.033589 	Counter: 21
# Train Epoch: 100 	Training Loss: 0.006216 	Validation Loss: 0.031027 	Counter: 22
# Train Epoch: 101 	Training Loss: 0.006284 	Validation Loss: 0.041198 	Counter: 23
# Train Epoch: 102 	Training Loss: 0.012817 	Validation Loss: 0.033305 	Counter: 24
# Train Epoch: 103 	Training Loss: 0.006408 	Validation Loss: 0.034601 	Counter: 25
# Train Epoch: 104 	Training Loss: 0.006860 	Validation Loss: 0.033612 	Counter: 26
# Train Epoch: 105 	Training Loss: 0.008717 	Validation Loss: 0.032833 	Counter: 27
# Train Epoch: 106 	Training Loss: 0.010754 	Validation Loss: 0.033855 	Counter: 28
# Train Epoch: 107 	Training Loss: 0.009122 	Validation Loss: 0.032571 	Counter: 29
# Train Epoch: 108 	Training Loss: 0.007098 	Validation Loss: 0.031923 	Counter: 30
# Training Done
#
# Training Time:  129.50429368019104
# Saving this newly trained model and info in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvs\pvs_BiMod_5_LSTM_v1 .pickle
# aavs:  ['LAMP_h7.5_p15_a135_hh3_pp20_aa165_s0-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa60_s12-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa15_s2-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa180_s4-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa180_s2-0000001.mot']
# avaa:  ['LAMP_h7.5_p15_a45_hh3_pp20_aa300_s8-0000001.mot'
#  'LAMP_h7.5_p15_a90_hh3_pp20_aa345_s8-0000001.mot'
#  'LAMP_h7.5_p15_a120_hh3_pp20_aa120_s8-0000001.mot'
#  'LAMP_h7.5_p15_a30_hh3_pp20_aa105_s8-0000001.mot'
#  'LAMP_h7.5_p15_a60_hh3_pp20_aa330_s8-0000001.mot']
# avhh:  ['LAMP_h7.5_p15_a120_hh4.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a0_hh4_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a315_hh1_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a255_hh1_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a0_hh3_pp20_aa270_s8-0000001.mot']
# avpp:  ['LAMP_h7.5_p15_a240_hh3_pp24_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a0_hh3_pp19_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a105_hh3_pp17_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a300_hh3_pp21_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a75_hh3_pp22_aa270_s8-0000001.mot']
# avs:  ['LAMP_h7.5_p15_a195_hh3_pp20_aa270_s4-0000001.mot'
#  'LAMP_h7.5_p15_a60_hh3_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7.5_p15_a120_hh3_pp20_aa270_s0-0000001.mot'
#  'LAMP_h7.5_p15_a315_hh3_pp20_aa270_s6-0000001.mot'
#  'LAMP_h7.5_p15_a60_hh3_pp20_aa270_s10-0000001.mot']
# hhvaa:  ['LAMP_h7.5_p15_a135_hh5.5_pp20_aa60_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh4_pp20_aa330_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh2.5_pp20_aa210_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh4.5_pp20_aa75_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh1.5_pp20_aa255_s8-0000001.mot']
# hhvpp:  ['LAMP_h7.5_p15_a135_hh3.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp22_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5_pp23_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh2.5_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5_pp21_aa270_s8-0000001.mot']
# hhvs:  ['LAMP_h7.5_p15_a135_hh5_pp20_aa270_s16-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5.5_pp20_aa270_s0-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh1_pp20_aa270_s2-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh4_pp20_aa270_s10-0000001.mot']
# hva:  ['LAMP_h9.5_p15_a210_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p15_a165_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a240_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p15_a255_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h9_p15_a135_hh3_pp20_aa270_s8-0000001.mot']
# hvaa:  ['LAMP_h8_p15_a135_hh3_pp20_aa45_s8-0000001.mot'
#  'LAMP_h8_p15_a135_hh3_pp20_aa60_s8-0000001.mot'
#  'LAMP_h8.5_p15_a135_hh3_pp20_aa135_s8-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa30_s8-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa195_s8-0000001.mot']
# hvhh:  ['LAMP_h6.5_p15_a135_hh5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh2_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p15_a135_hh5.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7_p15_a135_hh4_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8_p15_a135_hh2.5_pp20_aa270_s8-0000001.mot']
# hvp:  ['LAMP_h6.5_p13_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h6.5_p17_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7_p19_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p18_a135_hh3_pp20_aa270_s8-0000001.mot']
# hvpp:  ['LAMP_h6_p15_a135_hh3_pp17_aa270_s8-0000001.mot'
#  'LAMP_h9_p15_a135_hh3_pp16_aa270_s8-0000001.mot'
#  'LAMP_h9_p15_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h9.5_p15_a135_hh3_pp16_aa270_s8-0000001.mot'
#  'LAMP_h6_p15_a135_hh3_pp24_aa270_s8-0000001.mot']
# hvs:  ['LAMP_h5.5_p15_a135_hh3_pp20_aa270_s10-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7_p15_a135_hh3_pp20_aa270_s4-0000001.mot'
#  'LAMP_h9.5_p15_a135_hh3_pp20_aa270_s10-0000001.mot']
# ppvaa:  ['LAMP_h7.5_p15_a135_hh3_pp18_aa300_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa315_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp22_aa240_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp24_aa150_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp18_aa285_s8-0000001.mot']
# ppvs:  ['LAMP_h7.5_p15_a135_hh3_pp23_aa270_s4-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa270_s12-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp16_aa270_s12-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa270_s2-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa270_s0-0000001.mot']
# pvaa:  ['LAMP_h7.5_p15_a135_hh3_pp20_aa45_s8-0000001.mot'
#  'LAMP_h7.5_p18_a135_hh3_pp20_aa30_s8-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa135_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa225_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh3_pp20_aa15_s8-0000001.mot']
# pvhh:  ['LAMP_h7.5_p11_a135_hh1_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p16_a135_hh3.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh4.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p18_a135_hh3.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p16_a135_hh1.5_pp20_aa270_s8-0000001.mot']
# pvpp:  ['LAMP_h7.5_p19_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p11_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p13_a135_hh3_pp23_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh3_pp21_aa270_s8-0000001.mot']
# pvs:  ['LAMP_h7.5_p13_a135_hh3_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7.5_p17_a135_hh3_pp20_aa270_s2-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa270_s4-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa270_s16-0000001.mot'
#  'LAMP_h7.5_p13_a135_hh3_pp20_aa270_s6-0000001.mot']

# %%
fig = plt.figure(figsize=(10,10))

plt.plot(exp_list,t,'o')
plt.xticks(rotation=90)
plt.ylabel('Time (s)')
plt.xlabel('Experiment')
plt.title('Training Time for New LSTMs in Bimodal Seas, N=5')
plt.show()

# %%
def generate_test_output(experiment='', N=5, save_folder=''):
    """Given an experiment generate and save output files"""
    
    # ID Experiment for tracking
    print("EXPERIMENT: ", experiment)

    exp_PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\{experiment}'

    # Setup GPU Support
    print("Cuda available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        torch.cuda.empty_cache()  # to avoid some rare errors.

    # Check if using CPU or GPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Set parameters
    args = UserInputArgs()
    data_info_args = DataInfoArgs()
    save_data_args = SaveDataArgs()

    # Load the LSTM
    args.model_load_filename = exp_PATH + f'\\{experiment}_BiMod_{N}_LSTM'
    network, std_factors = load_lstm_info(args)
    network.to(device)

    # Create list of eligible files to train on
    test_files = [f for f in os.listdir(exp_PATH + '\\LAMP_files') if f.endswith('3.mot')]

    # test_files = files
    data_info_args.test_lamp = [exp_PATH + '\\LAMP_files\\' + f.removesuffix('.mot') for f in test_files]
    data_info_args.test_sc = [exp_PATH + '\\SimpleCode_files\\' + f.replace('LAMP','SC').removesuffix('.mot') for f in test_files]

    # Setup Derived Args
    derived_args = DerivedArgs(args, data_info_args)
    derived_args.test_batch_size = int(derived_args.num_test_realizations * args.time_res / 9)
    # print("No of train realizations: ", derived_args.num_train_realizations)
    # print("No of val realizations: ", derived_args.num_val_realizations)
    print("No of test realizations: ", derived_args.num_test_realizations)
    # print("No of realizations: ", derived_args.num_realizations)
    # print("Train batch size: ", derived_args.train_batch_size)
    # print("Val batch size: ", derived_args.val_batch_size)
    print("Test batch size: ", derived_args.test_batch_size)

    # Load the training and validation data
    test_input, test_target, test_sc = load_and_standardize(data_info_args.test_sc, data_info_args.test_lamp, args, std_factors)

    # Reshape the data to take into account the time resolution
    test_input, test_target = reshape_for_time_resolution(test_input, test_target, args)

    # Create Dataset objects for each of our train/val/test sets
    test_dataset = S2LDataset(test_input, test_target)

    # Create testing dataloader
    test_loader = DataLoader(test_dataset, batch_size=derived_args.test_batch_size)

    # Display dataset information
    # print("\nReshaped the following data:")
    # print(f"train_input has shape	{train_input.shape}")
    # print(f"train_target has shape	{train_target.shape}")
    # print(f"val_input has shape 	{val_input.shape}")
    # print(f"val_target has shape 	{val_target.shape}")
    print(f"test_input has shape 	{test_input.shape}")
    print(f"test_target has shape 	{test_target.shape}")
    # realization_length = train_input.shape[1] * args.time_res

    # initialize our optimizer. We'll use Adam
    optimizer = torch.optim.Adam(network.parameters(), lr=args.lr)

    start_time = time.time()
    test_lstm_output = test(network,device,test_loader,args.val_fun_hyp,derived_args.num_test_realizations,args.time_res,True,)
    end_time = time.time()
    testTime = end_time - start_time
    print("Testing Time: ", testTime)
    # print("\ntrain output shape", train_lstm_output.shape)
    # print("val output shape  ", val_lstm_output.shape)
    print("test output shape ", test_lstm_output.shape)
    print("Time to produce output for ",derived_args.num_realizations," realizations:",(end_time - start_time),)

    # Reshape our input and targets to be same shape as output
    # train_input, train_target, train_lstm_output = reshape_full_series(train_input, train_target, train_lstm_output, args)
    # val_input, val_target, val_lstm_output = reshape_full_series(val_input, val_target, val_lstm_output, args)
    test_input, test_target, test_lstm_output = reshape_full_series(test_input, test_target, test_lstm_output, args)

    # Unstandardize
    # train_target, train_lstm_output = unstandardize_all_data(train_target, train_lstm_output, std_factors, args)
    # val_target, val_lstm_output = unstandardize_all_data(val_target, val_lstm_output, std_factors, args)
    test_target, test_lstm_output = unstandardize_all_data(test_target, test_lstm_output, std_factors, args)

    # # Print error report
    # print("\nLSTM Error Results:")
    # print_error_report(train_lstm_output,val_lstm_output,test_lstm_output,train_target,val_target,test_target,args,)
    
    # Save the output
    save_data_args.test = list(range(0,len(data_info_args.test_sc)))
    save_data_args.output_path = exp_PATH + f'\\{save_folder}\\'
    print("Saving output to ",save_data_args.output_path)
    save_lstm_test_results(test_lstm_output,save_data_args,data_info_args,args,std_factors,)
    print('')

# %%
PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\'
ignore = ['Cases_files', '.ipynb_checkpoints','SecAngleOnly_test','__pycache__']
for exp in os.listdir(PATH):
    if os.path.isdir(PATH + exp) and exp not in ignore:
        try:
            generate_test_output(exp,N=5,save_folder='output_files_BiMod2_30_5_v1')
        except Exception as e:
            logging.error(traceback.format_exc())
            print('ERROR in ', exp)
            print('\n\n\n')
            continue
# Out:
# EXPERIMENT:  aavs
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\aavs\aavs_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.4257254600524902
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.4257254600524902
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\aavs\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  avaa
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avaa\avaa_BiMod_5_LSTM .pickle
# No of test realizations:  288
# Test batch size:  288
# full series simple (input) shape  (288, 17990, 4)
# full series lamp (target) shape  (288, 17990, 3)
# test_input has shape 	(2592, 1998, 4)
# test_target has shape 	(2592, 1998, 3)
# Testing Time:  2.6142470836639404
# test output shape  (2592, 1998, 3)
# Time to produce output for  450  realizations: 2.6142470836639404
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avaa\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  avhh
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avhh\avhh_BiMod_5_LSTM .pickle
# No of test realizations:  240
# Test batch size:  240
# full series simple (input) shape  (240, 17990, 4)
# full series lamp (target) shape  (240, 17990, 3)
# test_input has shape 	(2160, 1998, 4)
# test_target has shape 	(2160, 1998, 3)
# Testing Time:  1.6769416332244873
# test output shape  (2160, 1998, 3)
# Time to produce output for  402  realizations: 1.6769416332244873
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avhh\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  avpp
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avpp\avpp_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.0899360179901123
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.0899360179901123
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avpp\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  avs
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avs\avs_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.112454891204834
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.112454891204834
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avs\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hhvaa
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvaa\hhvaa_BiMod_5_LSTM .pickle
# No of test realizations:  240
# Test batch size:  240
# full series simple (input) shape  (240, 17990, 4)
# full series lamp (target) shape  (240, 17990, 3)
# test_input has shape 	(2160, 1998, 4)
# test_target has shape 	(2160, 1998, 3)
# Testing Time:  1.4862761497497559
# test output shape  (2160, 1998, 3)
# Time to produce output for  402  realizations: 1.4862761497497559
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvaa\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hhvpp
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvpp\hhvpp_BiMod_5_LSTM .pickle
# No of test realizations:  90
# Test batch size:  90
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
# test_input has shape 	(810, 1998, 4)
# test_target has shape 	(810, 1998, 3)
# Testing Time:  0.4664008617401123
# test output shape  (810, 1998, 3)
# Time to produce output for  252  realizations: 0.4664008617401123
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvpp\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hhvs
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvs\hhvs_BiMod_5_LSTM .pickle
# No of test realizations:  90
# Test batch size:  90
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
# test_input has shape 	(810, 1998, 4)
# test_target has shape 	(810, 1998, 3)
# Testing Time:  0.5284528732299805
# test output shape  (810, 1998, 3)
# Time to produce output for  252  realizations: 0.5284528732299805
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvs\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hva
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hva\hva_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.2340600490570068
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.2340600490570068
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hva\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hvaa
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvaa\hvaa_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.2155437469482422
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.2155437469482422
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvaa\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hvhh
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvhh\hvhh_BiMod_5_LSTM .pickle
# No of test realizations:  90
# Test batch size:  90
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
# test_input has shape 	(810, 1998, 4)
# test_target has shape 	(810, 1998, 3)
# Testing Time:  0.41585707664489746
# test output shape  (810, 1998, 3)
# Time to produce output for  252  realizations: 0.41585707664489746
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvhh\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hvp
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvp\hvp_BiMod_5_LSTM .pickle
# No of test realizations:  81
# Test batch size:  81
# ERROR:root:Traceback (most recent call last):
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\2681196803.py", line 6, in <module>
#     generate_test_output(exp,N=5,save_folder='output_files_BiMod2_30_5_v1')
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\1594164829.py", line 46, in generate_test_output
#     test_input, test_target, test_sc = load_and_standardize(data_info_args.test_sc, data_info_args.test_lamp, args, std_factors)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\load_and_standardize.py", line 48, in load_and_standardize
#     lstm_inputs, target_outputs = load_fullseries(
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\load_and_standardize.py", line 38, in load_fullseries
#     np.concatenate((simple_vbm_data, simple_motion_data, wave_data), axis=1)
#   File "<__array_function__ internals>", line 180, in concatenate
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 17990 and the array at index 2 has size 9499
# ERROR in  hvp
#
#
#
#
# EXPERIMENT:  hvpp
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvpp\hvpp_BiMod_5_LSTM .pickle
# No of test realizations:  81
# Test batch size:  81
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
# test_input has shape 	(729, 1998, 4)
# test_target has shape 	(729, 1998, 3)
# Testing Time:  0.38433027267456055
# test output shape  (729, 1998, 3)
# Time to produce output for  243  realizations: 0.38433027267456055
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvpp\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  hvs
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvs\hvs_BiMod_5_LSTM .pickle
# No of test realizations:  81
# Test batch size:  81
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
# test_input has shape 	(729, 1998, 4)
# test_target has shape 	(729, 1998, 3)
# Testing Time:  0.36231184005737305
# test output shape  (729, 1998, 3)
# Time to produce output for  243  realizations: 0.36231184005737305
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvs\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  ppvaa
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\ppvaa\ppvaa_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.2310569286346436
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.2310569286346436
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\ppvaa\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  ppvs
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\ppvs\ppvs_BiMod_5_LSTM .pickle
# No of test realizations:  81
# Test batch size:  81
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
# test_input has shape 	(729, 1998, 4)
# test_target has shape 	(729, 1998, 3)
# Testing Time:  0.43337178230285645
# test output shape  (729, 1998, 3)
# Time to produce output for  243  realizations: 0.43337178230285645
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\ppvs\output_files_BiMod2_30_5_v1\
# ERROR:root:Traceback (most recent call last):
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\2681196803.py", line 6, in <module>
#     generate_test_output(exp,N=5,save_folder='output_files_BiMod2_30_5_v1')
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\1594164829.py", line 24, in generate_test_output
#     network, std_factors = load_lstm_info(args)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\save_lstm.py", line 23, in load_lstm_info
#     loaded_lstm = pickle.load(open(user_input_args.model_load_filename+".pickle", "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: 'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\pva\\pva_BiMod_5_LSTM.pickle'
# EXPERIMENT:  pva
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pva\pva_BiMod_5_LSTM .pickle
# ERROR in  pva
#
#
#
#
# EXPERIMENT:  pvaa
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvaa\pvaa_BiMod_5_LSTM .pickle
# No of test realizations:  216
# Test batch size:  216
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
# test_input has shape 	(1944, 1998, 4)
# test_target has shape 	(1944, 1998, 3)
# Testing Time:  1.441237449645996
# test output shape  (1944, 1998, 3)
# Time to produce output for  378  realizations: 1.441237449645996
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvaa\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  pvhh
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvhh\pvhh_BiMod_5_LSTM .pickle
# No of test realizations:  90
# Test batch size:  90
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
# test_input has shape 	(810, 1998, 4)
# test_target has shape 	(810, 1998, 3)
# Testing Time:  0.5769953727722168
# test output shape  (810, 1998, 3)
# Time to produce output for  252  realizations: 0.5769953727722168
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvhh\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  pvpp
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvpp\pvpp_BiMod_5_LSTM .pickle
# No of test realizations:  81
# Test batch size:  81
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
# test_input has shape 	(729, 1998, 4)
# test_target has shape 	(729, 1998, 3)
# Testing Time:  0.5484714508056641
# test output shape  (729, 1998, 3)
# Time to produce output for  243  realizations: 0.5484714508056641
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvpp\output_files_BiMod2_30_5_v1\
#
# EXPERIMENT:  pvs
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvs\pvs_BiMod_5_LSTM .pickle
# No of test realizations:  81
# Test batch size:  81
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
# test_input has shape 	(729, 1998, 4)
# test_target has shape 	(729, 1998, 3)
# Testing Time:  0.4498870372772217
# test output shape  (729, 1998, 3)
# Time to produce output for  243  realizations: 0.4498870372772217
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvs\output_files_BiMod2_30_5_v1\

# %% [markdown]
# #### Transfer Learning Network

# %% [markdown]
# Copy medium network, train with same 5 files from bimodal network.

# %%
print("Cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    torch.cuda.empty_cache()  # to avoid some rare errors.

# Check if using CPU or GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set parameters
args = UserInputArgs()
plot_args = PlottingArgs()
data_info_args = DataInfoArgs()
save_data_args = SaveDataArgs()

# args.training_mode = False

# Load original LSTM
args.model_load_filename = 'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\MED LSTM\\MED2_30'
network, std_factors = load_lstm_info(args)
network.to(device)
# Out:
# Cuda available: True
# Loading LSTM Saved in:  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\MED LSTM\MED2_30 .pickle
# LSTM(
#   (lstm): LSTM(4, 30, num_layers=2, batch_first=True)
#   (linear): Linear(in_features=30, out_features=3, bias=True)
# )

# %%
def generateOutput(experiment, n=5, train_mode=True, save_folder='',training_files={}):
    """Given an experiment and training sample size, generate and save output files"""
    print("EXPERIMENT: ", experiment)
    
    # Create list of eligible files to train on
    exp_PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\{experiment}'
    files = [f for f in os.listdir(exp_PATH + '\\LAMP_files') if f.endswith('1.mot')]

    # Establish test files list (since we're testing on all in a folder)
    test_files = [f.replace('1.mot','3.mot') for f in files]
    # test_files = files
    data_info_args.test_lamp = [exp_PATH + '\\LAMP_files\\' + f.removesuffix('.mot') for f in test_files]
    data_info_args.test_sc = [exp_PATH + '\\SimpleCode_files\\' + f.replace('LAMP','SC').removesuffix('.mot') for f in test_files]

    # Copy the MED LSTM
    model = copy.deepcopy(network)

    # Setup GPU Support
    print("Cuda available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        torch.cuda.empty_cache()  # to avoid some rare errors.

    # Check if using CPU or GPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.to(device)

    # Use files from bimodal network training
    # train_files = np.random.choice(files, size=n, replace = False)
    train_files = training_files[experiment]
    print("Training on: ", train_files)
    val_files = [f.replace('1.mot','2.mot') for f in train_files]
    # Shorten val_files to 20% of train_files
    val_files = np.random.choice(val_files, size=int(.2*len(val_files)), replace = False)

    # establish the lamp and sc training file paths
    data_info_args.train_lamp = [exp_PATH + '\\LAMP_files\\' + f.removesuffix('.mot') for f in train_files]
    data_info_args.train_sc = [exp_PATH + '\\SimpleCode_files\\' + f.replace('LAMP','SC').removesuffix('.mot') for f in train_files]

    # establish the lamp and sc validation file paths
    data_info_args.val_lamp= [exp_PATH + '\\LAMP_files\\' + f.removesuffix('.mot') for f in val_files]
    data_info_args.val_sc = [exp_PATH + '\\SimpleCode_files\\' + f.replace('LAMP','SC').removesuffix('.mot') for f in val_files]

    # Setup Derived Args
    derived_args = DerivedArgs(args, data_info_args)
    derived_args.test_batch_size = int(derived_args.num_test_realizations * args.time_res / 9)
    # print("No of train realizations: ", derived_args.num_train_realizations)
    # print("No of val realizations: ", derived_args.num_val_realizations)
    # print("No of test realizations: ", derived_args.num_test_realizations)
    # print("No of realizations: ", derived_args.num_realizations)
    # print("Train batch size: ", derived_args.train_batch_size)
    # print("Val batch size: ", derived_args.val_batch_size)
    # print("Test batch size: ", derived_args.test_batch_size)

    # Load the training and validation data
    train_input, train_target, train_sc = load_and_standardize(data_info_args.train_sc, data_info_args.train_lamp, args, std_factors)
    val_input, val_target, val_sc = load_and_standardize(data_info_args.val_sc, data_info_args.val_lamp, args, std_factors)
    test_input, test_target, test_sc = load_and_standardize(data_info_args.test_sc, data_info_args.test_lamp, args, std_factors)

    # Reshape the data to take into account the time resolution
    train_input, train_target = reshape_for_time_resolution(train_input, train_target, args)
    val_input, val_target = reshape_for_time_resolution(val_input, val_target, args)
    test_input, test_target = reshape_for_time_resolution(test_input, test_target, args)

    # Create Dataset objects for each of our train/val/test sets
    train_dataset = S2LDataset(train_input, train_target)
    val_dataset = S2LDataset(val_input, val_target)
    test_dataset = S2LDataset(test_input, test_target)

    # Create a PyTorch dataloader for each train/val set. Test set isn't needed until later
    train_loader = DataLoader(train_dataset, batch_size=derived_args.train_batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=derived_args.val_batch_size)

    # Create testing dataloader
    test_loader = DataLoader(test_dataset, batch_size=derived_args.test_batch_size)

    # Display dataset information
    # print("\nReshaped the following data:")
    # print(f"train_input has shape	{train_input.shape}")
    # print(f"train_target has shape	{train_target.shape}")
    # print(f"val_input has shape 	{val_input.shape}")
    # print(f"val_target has shape 	{val_target.shape}")
    # print(f"test_input has shape 	{test_input.shape}")
    # print(f"test_target has shape 	{test_target.shape}")
    realization_length = train_input.shape[1] * args.time_res

    # initialize our optimizer. We'll use Adam
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    # Begin Training
    if train_mode == True:
        best_val_loss = float("inf")
        best_loss_counter = 0
        print("\n Beginning Training")
        start_time = time.time()
        for epoch in range(1, args.epochs + 1):
            train_loss = train(model, device, train_loader, optimizer, args.train_fun_hyp)
            val_loss = test(model, device, val_loader, args.val_fun_hyp)
            if val_loss < 0.95 * best_val_loss:
                best_val_loss = val_loss
                best_loss_counter = 0
                torch.save(model.state_dict(), "recently_trained_model.pt")
            else:
                best_loss_counter += 1
            if best_loss_counter > 30:
                break
            # print("Train Epoch: {:02d} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tCounter: {:02d}".format(epoch, train_loss, val_loss, best_loss_counter))
        print("Training Done\n")
        end_time = time.time()
        trainTime = end_time - start_time
        print("Training Time: ", trainTime)
        model.load_state_dict(torch.load("recently_trained_model.pt"))  # restoring the best found network based on validation data

    start_time = time.time()
    train_lstm_output = test(model,device,train_loader,args.val_fun_hyp,derived_args.num_train_realizations,args.time_res,True,)
    val_lstm_output = test(model,device,val_loader,args.val_fun_hyp,derived_args.num_val_realizations,args.time_res,True,)
    test_lstm_output = test(model,device,test_loader,args.val_fun_hyp,derived_args.num_test_realizations,args.time_res,True,)
    end_time = time.time()
    testTime = end_time - start_time
    print("Testing Time: ", testTime)
    print("\ntrain output shape", train_lstm_output.shape)
    print("val output shape  ", val_lstm_output.shape)
    print("test output shape ", test_lstm_output.shape)
    print("Time to produce output for ",derived_args.num_realizations," realizations:",(end_time - start_time),)

    # Reshape our input and targets to be same shape as output
    train_input, train_target, train_lstm_output = reshape_full_series(train_input, train_target, train_lstm_output, args)
    val_input, val_target, val_lstm_output = reshape_full_series(val_input, val_target, val_lstm_output, args)
    test_input, test_target, test_lstm_output = reshape_full_series(test_input, test_target, test_lstm_output, args)

    # Unstandardize
    train_target, train_lstm_output = unstandardize_all_data(train_target, train_lstm_output, std_factors, args)
    val_target, val_lstm_output = unstandardize_all_data(val_target, val_lstm_output, std_factors, args)
    test_target, test_lstm_output = unstandardize_all_data(test_target, test_lstm_output, std_factors, args)

    # Print error report
    print("\nLSTM Error Results:")
    print_error_report(train_lstm_output,val_lstm_output,test_lstm_output,train_target,val_target,test_target,args,)
    
    # Save the output
    save_data_args.test = list(range(0,len(data_info_args.test_sc)))
    save_data_args.output_path = exp_PATH + f'\\{save_folder}\\'
    print("Saving output to ",save_data_args.output_path)
    save_lstm_results(train_lstm_output,val_lstm_output,test_lstm_output,save_data_args,data_info_args,args,std_factors,)
    print('')

# %%
PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\'
ignore = ['Cases_files', '.ipynb_checkpoints','SecAngleOnly_test','__pycache__']
for exp in os.listdir(PATH):
    if os.path.isdir(PATH + exp) and exp not in ignore:
        try:
            generateOutput(exp,n=5,train_mode=True,save_folder='output_files_MED2_30_5_v1',training_files=training_files)
        except Exception as e:
            logging.error(traceback.format_exc())
            print('ERROR in ', exp)
            continue
# Out:
# EXPERIMENT:  aavs
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh3_pp20_aa165_s0-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa60_s12-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa15_s2-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa180_s4-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa180_s2-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  83.47024393081665
# Testing Time:  2.7218399047851562
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 2.7218399047851562
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(28.5058, dtype=torch.float64)
# Amplitude Magnified:  tensor(3302.8540, dtype=torch.float64)
# Peak MSE:             tensor(37.4305, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.4020, dtype=torch.float64)
# Amplitude Magnified:  tensor(42.4238, dtype=torch.float64)
# Peak MSE:             tensor(0.3678, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(2.2317, dtype=torch.float64)
# Amplitude Magnified:  tensor(115.3646, dtype=torch.float64)
# Peak MSE:             tensor(1.7929, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\aavs\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  avaa
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a45_hh3_pp20_aa300_s8-0000001.mot'
#  'LAMP_h7.5_p15_a90_hh3_pp20_aa345_s8-0000001.mot'
#  'LAMP_h7.5_p15_a120_hh3_pp20_aa120_s8-0000001.mot'
#  'LAMP_h7.5_p15_a30_hh3_pp20_aa105_s8-0000001.mot'
#  'LAMP_h7.5_p15_a60_hh3_pp20_aa330_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (288, 17990, 4)
# full series lamp (target) shape  (288, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  87.49620318412781
# Testing Time:  2.8314335346221924
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (2592, 1998, 3)
# Time to produce output for  294  realizations: 2.8314335346221924
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(43.1356, dtype=torch.float64)
# Amplitude Magnified:  tensor(6346.4157, dtype=torch.float64)
# Peak MSE:             tensor(57.8838, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(1.2757, dtype=torch.float64)
# Amplitude Magnified:  tensor(32.6360, dtype=torch.float64)
# Peak MSE:             tensor(1.4151, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(3.5859, dtype=torch.float64)
# Amplitude Magnified:  tensor(207.1269, dtype=torch.float64)
# Peak MSE:             tensor(3.1378, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avaa\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  avhh
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a120_hh4.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a0_hh4_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a315_hh1_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a255_hh1_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a0_hh3_pp20_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (240, 17990, 4)
# full series lamp (target) shape  (240, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  96.53597235679626
# Testing Time:  2.653280735015869
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (2160, 1998, 3)
# Time to produce output for  246  realizations: 2.653280735015869
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(22.6050, dtype=torch.float64)
# Amplitude Magnified:  tensor(2487.6451, dtype=torch.float64)
# Peak MSE:             tensor(32.3281, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(1.8739, dtype=torch.float64)
# Amplitude Magnified:  tensor(163.6540, dtype=torch.float64)
# Peak MSE:             tensor(1.7532, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(4.9777, dtype=torch.float64)
# Amplitude Magnified:  tensor(909.2529, dtype=torch.float64)
# Peak MSE:             tensor(5.4824, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avhh\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  avpp
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a240_hh3_pp24_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a0_hh3_pp19_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a105_hh3_pp17_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a300_hh3_pp21_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a75_hh3_pp22_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  90.34214878082275
# Testing Time:  1.6579248905181885
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 1.6579248905181885
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(45.0873, dtype=torch.float64)
# Amplitude Magnified:  tensor(7840.2498, dtype=torch.float64)
# Peak MSE:             tensor(60.7997, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.6211, dtype=torch.float64)
# Amplitude Magnified:  tensor(3.6290, dtype=torch.float64)
# Peak MSE:             tensor(0.5451, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(4.6748, dtype=torch.float64)
# Amplitude Magnified:  tensor(410.1254, dtype=torch.float64)
# Peak MSE:             tensor(5.0464, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avpp\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  avs
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a195_hh3_pp20_aa270_s4-0000001.mot'
#  'LAMP_h7.5_p15_a60_hh3_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7.5_p15_a120_hh3_pp20_aa270_s0-0000001.mot'
#  'LAMP_h7.5_p15_a315_hh3_pp20_aa270_s6-0000001.mot'
#  'LAMP_h7.5_p15_a60_hh3_pp20_aa270_s10-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  124.15370988845825
# Testing Time:  2.1798717975616455
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 2.1798717975616455
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(52.5223, dtype=torch.float64)
# Amplitude Magnified:  tensor(8937.3759, dtype=torch.float64)
# Peak MSE:             tensor(76.0612, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(1.3806, dtype=torch.float64)
# Amplitude Magnified:  tensor(189.8187, dtype=torch.float64)
# Peak MSE:             tensor(1.4539, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(5.2178, dtype=torch.float64)
# Amplitude Magnified:  tensor(604.6970, dtype=torch.float64)
# Peak MSE:             tensor(5.0965, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\avs\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hhvaa
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh5.5_pp20_aa60_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh4_pp20_aa330_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh2.5_pp20_aa210_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh4.5_pp20_aa75_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh1.5_pp20_aa255_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (240, 17990, 4)
# full series lamp (target) shape  (240, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  92.2237663269043
# Testing Time:  2.666792154312134
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (2160, 1998, 3)
# Time to produce output for  246  realizations: 2.666792154312134
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(8.2875, dtype=torch.float64)
# Amplitude Magnified:  tensor(709.0621, dtype=torch.float64)
# Peak MSE:             tensor(7.8931, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.7676, dtype=torch.float64)
# Amplitude Magnified:  tensor(46.6268, dtype=torch.float64)
# Peak MSE:             tensor(0.6971, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(1.7841, dtype=torch.float64)
# Amplitude Magnified:  tensor(135.4036, dtype=torch.float64)
# Peak MSE:             tensor(1.6277, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvaa\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hhvpp
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh3.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp22_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5_pp23_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh2.5_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5_pp21_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  100.90072441101074
# Testing Time:  1.2070379257202148
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (810, 1998, 3)
# Time to produce output for  96  realizations: 1.2070379257202148
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(7.3091, dtype=torch.float64)
# Amplitude Magnified:  tensor(500.1291, dtype=torch.float64)
# Peak MSE:             tensor(6.2188, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.1995, dtype=torch.float64)
# Amplitude Magnified:  tensor(13.9309, dtype=torch.float64)
# Peak MSE:             tensor(0.1913, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.3174, dtype=torch.float64)
# Amplitude Magnified:  tensor(24.4095, dtype=torch.float64)
# Peak MSE:             tensor(0.2769, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvpp\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hhvs
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh5_pp20_aa270_s16-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh5.5_pp20_aa270_s0-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh1_pp20_aa270_s2-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh4_pp20_aa270_s10-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  99.0571391582489
# Testing Time:  1.3751819133758545
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (810, 1998, 3)
# Time to produce output for  96  realizations: 1.3751819133758545
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(36.5713, dtype=torch.float64)
# Amplitude Magnified:  tensor(3954.6096, dtype=torch.float64)
# Peak MSE:             tensor(45.6291, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.4973, dtype=torch.float64)
# Amplitude Magnified:  tensor(32.1675, dtype=torch.float64)
# Peak MSE:             tensor(0.4395, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.6104, dtype=torch.float64)
# Amplitude Magnified:  tensor(51.0911, dtype=torch.float64)
# Peak MSE:             tensor(0.4985, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hhvs\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hva
# Cuda available: True
# Training on:  ['LAMP_h9.5_p15_a210_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p15_a165_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a240_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p15_a255_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h9_p15_a135_hh3_pp20_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  75.84318661689758
# Testing Time:  2.4085700511932373
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 2.4085700511932373
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(32.8036, dtype=torch.float64)
# Amplitude Magnified:  tensor(4053.9323, dtype=torch.float64)
# Peak MSE:             tensor(40.3013, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(2.1264, dtype=torch.float64)
# Amplitude Magnified:  tensor(132.0215, dtype=torch.float64)
# Peak MSE:             tensor(2.3630, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(17.8958, dtype=torch.float64)
# Amplitude Magnified:  tensor(3391.7971, dtype=torch.float64)
# Peak MSE:             tensor(19.7870, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hva\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hvaa
# Cuda available: True
# Training on:  ['LAMP_h8_p15_a135_hh3_pp20_aa45_s8-0000001.mot'
#  'LAMP_h8_p15_a135_hh3_pp20_aa60_s8-0000001.mot'
#  'LAMP_h8.5_p15_a135_hh3_pp20_aa135_s8-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa30_s8-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa195_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  88.09271550178528
# Testing Time:  1.832575798034668
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 1.832575798034668
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(5.2521, dtype=torch.float64)
# Amplitude Magnified:  tensor(548.5014, dtype=torch.float64)
# Peak MSE:             tensor(5.5344, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.7585, dtype=torch.float64)
# Amplitude Magnified:  tensor(88.6786, dtype=torch.float64)
# Peak MSE:             tensor(0.7851, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(2.2875, dtype=torch.float64)
# Amplitude Magnified:  tensor(155.8636, dtype=torch.float64)
# Peak MSE:             tensor(2.0327, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvaa\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hvhh
# Cuda available: True
# Training on:  ['LAMP_h6.5_p15_a135_hh5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh2_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p15_a135_hh5.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7_p15_a135_hh4_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8_p15_a135_hh2.5_pp20_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  50.118576765060425
# Testing Time:  0.7751650810241699
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (810, 1998, 3)
# Time to produce output for  96  realizations: 0.7751650810241699
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(2.6588, dtype=torch.float64)
# Amplitude Magnified:  tensor(243.4364, dtype=torch.float64)
# Peak MSE:             tensor(1.9937, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.5811, dtype=torch.float64)
# Amplitude Magnified:  tensor(76.4779, dtype=torch.float64)
# Peak MSE:             tensor(0.4915, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.6293, dtype=torch.float64)
# Amplitude Magnified:  tensor(78.7939, dtype=torch.float64)
# Peak MSE:             tensor(0.5738, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvhh\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hvp
# Cuda available: True
# Training on:  ['LAMP_h6.5_p13_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h6.5_p17_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7_p19_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h8.5_p18_a135_hh3_pp20_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# ERROR:root:Traceback (most recent call last):
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\609365706.py", line 6, in <module>
#     generateOutput(exp,n=5,train_mode=True,save_folder='output_files_MED2_30_5_v1',training_files=training_files)
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\960844863.py", line 58, in generateOutput
#     test_input, test_target, test_sc = load_and_standardize(data_info_args.test_sc, data_info_args.test_lamp, args, std_factors)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\load_and_standardize.py", line 48, in load_and_standardize
#     lstm_inputs, target_outputs = load_fullseries(
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\load_and_standardize.py", line 38, in load_fullseries
#     np.concatenate((simple_vbm_data, simple_motion_data, wave_data), axis=1)
#   File "<__array_function__ internals>", line 180, in concatenate
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 17990 and the array at index 2 has size 9499
# ERROR in  hvp
# EXPERIMENT:  hvpp
# Cuda available: True
# Training on:  ['LAMP_h6_p15_a135_hh3_pp17_aa270_s8-0000001.mot'
#  'LAMP_h9_p15_a135_hh3_pp16_aa270_s8-0000001.mot'
#  'LAMP_h9_p15_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h9.5_p15_a135_hh3_pp16_aa270_s8-0000001.mot'
#  'LAMP_h6_p15_a135_hh3_pp24_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  96.04705357551575
# Testing Time:  0.6875905990600586
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (729, 1998, 3)
# Time to produce output for  87  realizations: 0.6875905990600586
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(10.5445, dtype=torch.float64)
# Amplitude Magnified:  tensor(1353.9060, dtype=torch.float64)
# Peak MSE:             tensor(10.6983, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.1104, dtype=torch.float64)
# Amplitude Magnified:  tensor(3.9678, dtype=torch.float64)
# Peak MSE:             tensor(0.1003, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.3437, dtype=torch.float64)
# Amplitude Magnified:  tensor(34.1731, dtype=torch.float64)
# Peak MSE:             tensor(0.3079, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvpp\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  hvs
# Cuda available: True
# Training on:  ['LAMP_h5.5_p15_a135_hh3_pp20_aa270_s10-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa270_s8-0000001.mot'
#  'LAMP_h5.5_p15_a135_hh3_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7_p15_a135_hh3_pp20_aa270_s4-0000001.mot'
#  'LAMP_h9.5_p15_a135_hh3_pp20_aa270_s10-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  32.16064095497131
# Testing Time:  0.6995999813079834
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (729, 1998, 3)
# Time to produce output for  87  realizations: 0.6995999813079834
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(23.7396, dtype=torch.float64)
# Amplitude Magnified:  tensor(2231.0445, dtype=torch.float64)
# Peak MSE:             tensor(30.7572, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(1.9995, dtype=torch.float64)
# Amplitude Magnified:  tensor(245.5400, dtype=torch.float64)
# Peak MSE:             tensor(2.2702, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(1.0132, dtype=torch.float64)
# Amplitude Magnified:  tensor(109.8321, dtype=torch.float64)
# Peak MSE:             tensor(0.8496, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\hvs\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  ppvaa
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh3_pp18_aa300_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa315_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp22_aa240_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp24_aa150_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp18_aa285_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  47.017910957336426
# Testing Time:  1.3641738891601562
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 1.3641738891601562
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(5.8815, dtype=torch.float64)
# Amplitude Magnified:  tensor(409.4155, dtype=torch.float64)
# Peak MSE:             tensor(4.6781, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.6092, dtype=torch.float64)
# Amplitude Magnified:  tensor(54.5517, dtype=torch.float64)
# Peak MSE:             tensor(0.5132, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(2.1547, dtype=torch.float64)
# Amplitude Magnified:  tensor(123.6268, dtype=torch.float64)
# Peak MSE:             tensor(1.8997, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\ppvaa\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  ppvs
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh3_pp23_aa270_s4-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa270_s12-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp16_aa270_s12-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa270_s2-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp21_aa270_s0-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  43.29821491241455
# Testing Time:  0.6780827045440674
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (729, 1998, 3)
# Time to produce output for  87  realizations: 0.6780827045440674
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(34.3649, dtype=torch.float64)
# Amplitude Magnified:  tensor(3878.6865, dtype=torch.float64)
# Peak MSE:             tensor(45.4690, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.3604, dtype=torch.float64)
# Amplitude Magnified:  tensor(27.6660, dtype=torch.float64)
# Peak MSE:             tensor(0.3375, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.5798, dtype=torch.float64)
# Amplitude Magnified:  tensor(36.6876, dtype=torch.float64)
# Peak MSE:             tensor(0.4741, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\ppvs\output_files_MED2_30_5_v1\
# ERROR:root:Traceback (most recent call last):
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\609365706.py", line 6, in <module>
#     generateOutput(exp,n=5,train_mode=True,save_folder='output_files_MED2_30_5_v1',training_files=training_files)
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\960844863.py", line 30, in generateOutput
#     train_files = training_files[experiment]
# KeyError: 'pva'
# EXPERIMENT:  pva
# Cuda available: True
# ERROR in  pva
# EXPERIMENT:  pvaa
# Cuda available: True
# Training on:  ['LAMP_h7.5_p15_a135_hh3_pp20_aa45_s8-0000001.mot'
#  'LAMP_h7.5_p18_a135_hh3_pp20_aa30_s8-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa135_s8-0000001.mot'
#  'LAMP_h7.5_p15_a135_hh3_pp20_aa225_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh3_pp20_aa15_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (216, 17990, 4)
# full series lamp (target) shape  (216, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  38.168304681777954
# Testing Time:  1.4152166843414307
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (1944, 1998, 3)
# Time to produce output for  222  realizations: 1.4152166843414307
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(29.1833, dtype=torch.float64)
# Amplitude Magnified:  tensor(3026.6512, dtype=torch.float64)
# Peak MSE:             tensor(38.5904, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.9465, dtype=torch.float64)
# Amplitude Magnified:  tensor(180.3600, dtype=torch.float64)
# Peak MSE:             tensor(0.9038, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(1.8195, dtype=torch.float64)
# Amplitude Magnified:  tensor(115.6863, dtype=torch.float64)
# Peak MSE:             tensor(1.6801, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvaa\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  pvhh
# Cuda available: True
# Training on:  ['LAMP_h7.5_p11_a135_hh1_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p16_a135_hh3.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh4.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p18_a135_hh3.5_pp20_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p16_a135_hh1.5_pp20_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (90, 17990, 4)
# full series lamp (target) shape  (90, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  46.622071504592896
# Testing Time:  0.7301278114318848
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (810, 1998, 3)
# Time to produce output for  96  realizations: 0.7301278114318848
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(26.1145, dtype=torch.float64)
# Amplitude Magnified:  tensor(2207.1269, dtype=torch.float64)
# Peak MSE:             tensor(33.4901, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.4721, dtype=torch.float64)
# Amplitude Magnified:  tensor(51.7714, dtype=torch.float64)
# Peak MSE:             tensor(0.4855, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.4569, dtype=torch.float64)
# Amplitude Magnified:  tensor(53.7775, dtype=torch.float64)
# Peak MSE:             tensor(0.4622, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvhh\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  pvpp
# Cuda available: True
# Training on:  ['LAMP_h7.5_p19_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p11_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh3_pp18_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p13_a135_hh3_pp23_aa270_s8-0000001.mot'
#  'LAMP_h7.5_p12_a135_hh3_pp21_aa270_s8-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  38.18782138824463
# Testing Time:  0.6840872764587402
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (729, 1998, 3)
# Time to produce output for  87  realizations: 0.6840872764587402
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(33.0359, dtype=torch.float64)
# Amplitude Magnified:  tensor(3725.3832, dtype=torch.float64)
# Peak MSE:             tensor(41.6888, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.6024, dtype=torch.float64)
# Amplitude Magnified:  tensor(60.5685, dtype=torch.float64)
# Peak MSE:             tensor(0.5651, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.3596, dtype=torch.float64)
# Amplitude Magnified:  tensor(34.4390, dtype=torch.float64)
# Peak MSE:             tensor(0.3038, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvpp\output_files_MED2_30_5_v1\
#
#
# EXPERIMENT:  pvs
# Cuda available: True
# Training on:  ['LAMP_h7.5_p13_a135_hh3_pp20_aa270_s14-0000001.mot'
#  'LAMP_h7.5_p17_a135_hh3_pp20_aa270_s2-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa270_s4-0000001.mot'
#  'LAMP_h7.5_p14_a135_hh3_pp20_aa270_s16-0000001.mot'
#  'LAMP_h7.5_p13_a135_hh3_pp20_aa270_s6-0000001.mot']
# full series simple (input) shape  (5, 17990, 4)
# full series lamp (target) shape  (5, 17990, 3)
# full series simple (input) shape  (1, 17990, 4)
# full series lamp (target) shape  (1, 17990, 3)
# full series simple (input) shape  (81, 17990, 4)
# full series lamp (target) shape  (81, 17990, 3)
#
#  Beginning Training
# Training Done
#
# Training Time:  83.65990614891052
# Testing Time:  0.7101113796234131
#
# train output shape (45, 1998, 3)
# val output shape   (9, 1998, 3)
# test output shape  (729, 1998, 3)
# Time to produce output for  87  realizations: 0.7101113796234131
#
# LSTM Error Results:
# --------------------------------------------
# Training Data Errors:
# MSE:                  tensor(35.2960, dtype=torch.float64)
# Amplitude Magnified:  tensor(3716.6739, dtype=torch.float64)
# Peak MSE:             tensor(46.3694, dtype=torch.float64)
# --------------------------------------------
# Validation Data Errors:
# MSE:                  tensor(0.4593, dtype=torch.float64)
# Amplitude Magnified:  tensor(50.5210, dtype=torch.float64)
# Peak MSE:             tensor(0.4643, dtype=torch.float64)
# --------------------------------------------
# Test Data Errors:
# MSE:                  tensor(0.6475, dtype=torch.float64)
# Amplitude Magnified:  tensor(61.3352, dtype=torch.float64)
# Peak MSE:             tensor(0.5882, dtype=torch.float64)
# --------------------------------------------
# Saving output to  H:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\Experiment_ARCHIVE\Bimodal Test Sets\pvs\output_files_MED2_30_5_v1\

# %%
# def LSTMvLAMP_df(experiment="",LSTM_files='', realization=''):
    
#     from pathlib import Path
#     import pandas as pd

#     """Makes a dataframe comparing LSTM and LAMP outputs
#         experiment = folder name of the experiment"""

#     # Establish paths
#     exp_PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\{experiment}\\'

#     # network options
#     # nwOptions = ('original', 'new')
    
#     # No experiment or network given
#     if experiment == "" or LSTM_files == '':
#         return "INVALID EXPERIMENT OR NETWORK"

#     # Parse out the variables observed
#     v1 = experiment.partition("v")[0]  # Pulls first variable by taking string before "_", spliting at the "v"
#     v2 = experiment.partition("v")[2]  # 2nd variable

#     # LAMP path
#     LAMP_path = exp_PATH + "\\LAMP_files\\"

#     # LSTM data
#     exp_PATH += LSTM_files + '\\'

#     # Set experiment path
#     # if network.lower() == "original":
#     #     exp_PATH += "\\output_files_MED\\"
#     # elif network.lower() == "new":
#     #     exp_PATH += "\\output_files_MED2_30_50\\"

#     # Make the dataframe for LSTM
#     df_LSTM = pd.DataFrame(
#         columns=[v1, v2, "Zcg", "Roll", "Pitch"]
#     )  # Create cols for the altered variables in experiement and heave, roll, pitch

#     # step through every LSTM file in the experiement to get the SSA, and add to dataframe
#     for path in Path(exp_PATH).glob(f"*{realization}.txt"):
#         # Get the SSA's
#         SSA = get_LSTM_SSA(path)
#         # Get the variable combo for the file
#         trial = path.name.lstrip("lstm_output_for_SC_")
#         idx = trial.partition(v1)[2]
#         t1 = idx.partition("_")[0]
#         if v2 == "s":
#             idx = trial.partition(v2)[2]
#             t2 = idx.partition("-")[0]
#         else:
#             idx = trial.partition(v2)[2]
#             t2 = idx.partition("_")[0]

#         SSA[v1] = float(t1)
#         SSA[v2] = float(t2)

#         df_LSTM.loc[len(df_LSTM)] = SSA

#     df_LSTM = df_LSTM.sort_values(by=[v1, v2])

#     # Make the dataframe for LAMP
#     df_LAMP = pd.DataFrame(columns=[v1, v2, "Zcg", "Roll", "Pitch"])

#     # step through every LAMP file in the experiement to get the SSA, and add to dataframe
#     for path in Path(LAMP_path).glob(f"*{realization}.mot"):
#         # Get the SSA's
#         SSA = get_LAMP_SSA(path)
#         # Get the variable combo for the file
#         trial = path.name.lstrip("LAMP_")
#         idx = trial.partition(v1)[2]
#         t1 = idx.partition("_")[0]
#         if v2 == "s":
#             idx = trial.partition(v2)[2]
#             t2 = idx.partition("-")[0]
#         else:
#             idx = trial.partition(v2)[2]
#             t2 = idx.partition("_")[0]

#         SSA[v1] = float(t1)
#         SSA[v2] = float(t2)

#         df_LAMP.loc[len(df_LAMP)] = SSA

#     df_LAMP = df_LAMP.sort_values(by=[v1, v2])

#     # Establish new, final DF for heatmap
#     df_final = pd.DataFrame(columns=[v1, v2, "Zcg Error", "Roll Error", "Pitch Error"])
#     df_final[v1] = df_LSTM[v1]
#     df_final[v2] = df_LSTM[v2]

#     # find the absolute difference between each in the series
#     df_final["Zcg Error"] = np.abs(df_LSTM["Zcg"] - df_LAMP["Zcg"])
#     df_final["Roll Error"] = np.abs(df_LSTM["Roll"] - df_LAMP["Roll"])
#     df_final["Pitch Error"] = np.abs(df_LSTM["Pitch"] - df_LAMP["Pitch"])

#     # Return DF, v1 and v2 variables to pivot on, unique lists of v1, v2 to mark training
#     return df_final, v1, v2, df_final[v1].unique(), df_final[v2].unique()

# %%
# def makeHeatmap(top_network,bottom_network, experiment, parameter, realization, save_folder, train_files):
#     import seaborn as sns
#     from matplotlib.patches import Rectangle
#     """
#     Creates a heatmap of SSA error between unimodal LSTM and same LSTM trained with bimodal seas. Given a df of the form:
#     v1      v2    Zcg Error       Roll Error    Pitch Error
#     experiment = case file
#     network = network trained on
#     parameter = parameter we want to see
#     realizatino = realization you want to focus on
#     save_folder = folder to save in
#     train_files = dictionary of training files for each experiment used
#     """

#     # Renaming Based on Experiment ID
#     EXP_ID = {'aa': 'Secondary Heading', 'a': 'Primary Heading', 'hh': 'Secondary Height', 'h': 'Primary Height', 'pp': 'Secondary Period', 'p': 'Primary Period', 's': 'Ship Speed'}
#     EXP_ID_units = {'aa': r'$Secondary Heading (^{\circ})$', 'a': r'$Primary Heading (^{\circ})$', 'hh': 'Secondary Height (m)', 'h': 'Primary Height (m)', 'pp': 'Secondary Period (sec)', 'p': 'Primary Period (sec)', 's': 'Ship Speed (knots)'}
#     plot_ID = experiment.split('v')

#     # Set save path for the figure
#     SAVE_PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Transfer Learning Figures\\{save_folder}'

#     # Set units for color bar
#     if parameter == "Zcg Error":
#         units = "meters"
#     else:
#         units = r"$^{\circ}$"

#     # Set the fig and ax
#     fig, (axo, axn, axd) = plt.subplots(3, figsize=(16, 16), sharey=True)
#     # cbar_ax = fig.add_axes([0.91, 0.3, 0.03, 0.4])
#     cbar_ax = fig.add_axes([0.91, 0.425, 0.03, 0.4])
#     rbar_ax = fig.add_axes([0.91, 0.125, 0.03, 0.2])
#     fig.suptitle(f"{EXP_ID[plot_ID[0]]} vs {EXP_ID[plot_ID[1]]} Absolute SSA {parameter}", fontsize=18)
#     fig.supxlabel(f'{EXP_ID_units[plot_ID[0]]}')
#     fig.supylabel(f'{EXP_ID_units[plot_ID[1]]}')
#     colormap= sns.diverging_palette(0,145,sep=15,as_cmap=True)
#     cbar_ax.set_ylabel(units)

#     # get the Original dataset
#     dfo, v1, v2, v1_vals, v2_vals = LSTMvLAMP_df(experiment, 'output_files_'+top_network, realization)
#     resulto = dfo.pivot(index=v2, columns=v1, values=parameter)

#     # Set colorbar max value
#     vmax = resulto.max().max()

#     # get the new dataset
#     dfn, v1, v2, _, _ = LSTMvLAMP_df(experiment, 'output_files_'+bottom_network, realization)
#     resultn = dfn.pivot(index=v2, columns=v1, values=parameter)

#     # Set colorbar max value to that of new if it's more than med
#     if resultn.max().max() > vmax:
#         vmax = resultn.max().max()

#     # Plot original dataset
#     g1 = sns.heatmap(
#         resulto,cmap="Blues",ax=axo, cbar=True,vmax=vmax,cbar_ax=cbar_ax, # annot = True, fmt = ".2f"
#     )
#     g1.invert_yaxis()
#     if 'BiMod' in top_network:
#         g1.set_title("Bimodal Training, N=" + top_network[-1])
#     else:
#         g1.set_title("Transfer Learning, N=" + top_network[-1])
#     g1.set_xlabel('')
#     g1.set_ylabel('')

#     # get the new dataset
#     g2 = sns.heatmap(
#         resultn, cmap="Blues", ax=axn, cbar_kws={"label": units}, cbar=True, vmax=vmax, cbar_ax=cbar_ax, # annot = True, fmt = ".2f"
#     )
#     g2.invert_yaxis()
#     if 'BiMod' in bottom_network:
#         g2.set_title("Bimodal Training, N=" + bottom_network[-1])
#     else:
#         g2.set_title("Transfer Learning, N=" + bottom_network[-1])
#     g2.set_xlabel('')
#     g2.set_ylabel('')

#     # Plot a heatmap comparing the difference between the two.  Bigger is better b/c delta_orig - delta_new means new performed much better
#     dfc = dfn.copy()
#     cols =  dfo.columns.difference([v1,v2])
#     dfc[cols] = dfo[cols] - dfn[cols]
#     resultc = dfc.pivot(index=v2, columns=v1, values=parameter)

#     # set colorbar max and min values
#     vmax = resultc.max().max()
#     vmin = resultc.min().min()

#     g3 = sns.heatmap(
#         resultc, cmap=colormap, ax=axd, cbar_kws={'label': units, 'ticks':[vmin,0,vmax], 'format': '%.2f'}, cbar=True, center=0, cbar_ax=rbar_ax, # annot = True, fmt = ".2f"
#     )
#     g3.invert_yaxis()
#     g3.set_title("Delta")
#     g3.set_xlabel('')
#     g3.set_ylabel('')

#     # Find training boxes for later plotting
#     # z1 and z2 provide list to map indeces to v1 and v2 vals
#     z1 = list(range(0,len(v1_vals)))
#     z2 = list(range(0,len(v2_vals)))

#     # dictionary index mapping values to heatmap index
#     idx1 = dict(zip(v1_vals,z1))
#     idx2 = dict(zip(v2_vals,z2))

#     # list of tubles for the chosen training records
#     hatches = []

#     for file in train_files[experiment]:
#         val1 = float(file.partition(plot_ID[0])[2].partition('_')[0])
#         if plot_ID[1] == 's':
#             val2 = float(file.partition(plot_ID[1])[2].partition('-')[0])
#         else:
#             val2 = float(file.partition(plot_ID[1])[2].partition('_')[0])

#         # Plot the rectangles of training records on each heatmap
#         axo.add_patch(Rectangle((idx1[val1],idx2[val2]),1,1, fill=False, edgecolor='orange', lw=3))
#         axn.add_patch(Rectangle((idx1[val1],idx2[val2]),1,1, fill=False, edgecolor='orange', lw=3))
#         axd.add_patch(Rectangle((idx1[val1],idx2[val2]),1,1, fill=False, edgecolor='orange', lw=3))
#         hatches.append((idx1[val1],idx2[val2]))

#     # Save the figure
#     plt.savefig(f"{SAVE_PATH}\\{experiment}_{save_folder}_{parameter}_{realization}.png")

# %% [markdown]
# ### Testing HeatMaps

# %%
PATH = f'H:\\OneDrive - Massachusetts Institute of Technology\\Thesis\\SimpleCode_to_LAMP_LSTM\\Experiment_ARCHIVE\\Bimodal Test Sets\\'
ignore = ['Cases_files', '.ipynb_checkpoints','SecAngleOnly_test','__pycache__']
for exp in os.listdir(PATH):
    if os.path.isdir(PATH + exp) and exp not in ignore:
        try:
            makeHeatmap(top_network='BiMod2_30_5_v1',bottom_network='MED2_30_5_v1',experiment=exp, parameter="Zcg Error", realization='3', save_folder='TL5_vs_BiMod5_v1', train_files=training_files)
            plt.close()
            makeHeatmap(top_network='BiMod2_30_5_v1',bottom_network='MED2_30_5_v1',experiment=exp, parameter="Roll Error", realization='3', save_folder='TL5_vs_BiMod5_v1', train_files=training_files)
            plt.close()
            makeHeatmap(top_network='BiMod2_30_5_v1',bottom_network='MED2_30_5_v1',experiment=exp, parameter="Pitch Error", realization='3', save_folder='TL5_vs_BiMod5_v1', train_files=training_files)
            plt.close()
        except Exception as e:
            logging.error(traceback.format_exc())
            print('ERROR in ', exp)
            continue
# Out:
# ERROR:root:Traceback (most recent call last):
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\1294344805.py", line 6, in <module>
#     makeHeatmap(top_network='BiMod2_30_5_v1',bottom_network='MED2_30_5_v1',experiment=exp, parameter="Zcg Error", realization='3', save_folder='TL5_vs_BiMod5_v1', train_files=training_files)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\data_functions.py", line 208, in makeHeatmap
#     resulto = dfo.pivot(index=v2, columns=v1, values=parameter)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\frame.py", line 7885, in pivot
#     return pivot(self, index=index, columns=columns, values=values)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\pivot.py", line 520, in pivot
#     return indexed.unstack(columns_listlike)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\series.py", line 4157, in unstack
#     return unstack(self, level, fill_value)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\reshape.py", line 491, in unstack
#     unstacker = _Unstacker(
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\reshape.py", line 140, in __init__
#     self._make_selectors()
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\reshape.py", line 192, in _make_selectors
#     raise ValueError("Index contains duplicate entries, cannot reshape")
# ValueError: Index contains duplicate entries, cannot reshape
# ERROR in  hvp
# ERROR:root:Traceback (most recent call last):
#   File "C:\Users\jarod\AppData\Local\Temp\ipykernel_18832\1294344805.py", line 6, in <module>
#     makeHeatmap(top_network='BiMod2_30_5_v1',bottom_network='MED2_30_5_v1',experiment=exp, parameter="Zcg Error", realization='3', save_folder='TL5_vs_BiMod5_v1', train_files=training_files)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\data_functions.py", line 208, in makeHeatmap
#     resulto = dfo.pivot(index=v2, columns=v1, values=parameter)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\frame.py", line 7885, in pivot
#     return pivot(self, index=index, columns=columns, values=values)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\pivot.py", line 520, in pivot
#     return indexed.unstack(columns_listlike)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\series.py", line 4157, in unstack
#     return unstack(self, level, fill_value)
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\reshape.py", line 491, in unstack
#     unstacker = _Unstacker(
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\reshape.py", line 140, in __init__
#     self._make_selectors()
#   File "h:\OneDrive - Massachusetts Institute of Technology\Thesis\SimpleCode_to_LAMP_LSTM\venv\lib\site-packages\pandas\core\reshape\reshape.py", line 192, in _make_selectors
#     raise ValueError("Index contains duplicate entries, cannot reshape")
# ValueError: Index contains duplicate entries, cannot reshape
# ERROR in  pva

# %%
# makeHeatmap(top_network='BiMod2_30_5',bottom_network='MED2_30_5',experiment='avs', parameter="Zcg Error", realization='3', save_folder='TL5_vs_BiMod5', train_files=train_files)

# %% [markdown]
# try:
#     makeHeatmap(top_network='BiMod2_30_5',bottom_network='MED2_30_5',experiment='aavs', parameter="Zcg Error", realization='3', save_file='TL5_vs_BiMod5')
#     # makeHeatmap('aavs', "Roll Error", '3')
#     # makeHeatmap('aavs', "Pitch Error", '3')
# except Exception as e:
#     logging.error(traceback.format_exc())
